# %%
import os
import requests
cred_url = os.environ["QCLOUD_CONTAINER_INSTANCE_CREDENTIALS_URL"]
r = requests.get(cred_url)
secretId = r.json()["TmpSecretId"]
secretKey = r.json()["TmpSecretKey"]
token = r.json()["Token"]

# %%
import os
from qcloud_cos import CosConfig
from qcloud_cos import CosS3Client
from ti.utils import get_temporary_secret_and_token

#### 指定本地文件路径，可根据需要修改。
local_file = "/home/tione/notebook/data/train_final_626.zip"

#### 用户的存储桶，修改为存放所需数据文件的存储桶，存储桶获取参考腾讯云对象存储
bucket="hc-02-1258788535"

#### 用户的数据，修改为对应的数据文件路径，文件路径获取参考腾讯云对象存储
data_key="train_final_626.zip"

#### 获取用户临时密钥
secret_id, secret_key, token = get_temporary_secret_and_token()
config = CosConfig(Region=os.environ.get('REGION'), SecretId=secret_id, SecretKey=secret_key, Token=token, Scheme='https')
client = CosS3Client(config)

####  获取文件到本地
response = client.get_object(
    Bucket=bucket,
    Key=data_key,
)
response['Body'].get_stream_to_file(local_file)

# %%
import pandas as pd 
import numpy as np 
from tqdm import tqdm 
import datetime, time 
from utils import distance, haversine, standard, pad_seq 
from scipy.stats import skew, kurtosis
from zipfile import ZipFile
from collections import Counter 

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
# %%time

myzip=ZipFile('data/train_final_626.zip')
f=myzip.open('train_final_626.csv')
train_df=pd.read_csv(f)
print(train_df)
f.close()
myzip.close() 

train_df.drop_duplicates(['loadingOrder', 'label'], inplace=True)
test_df = pd.read_csv("data/test_create_final.csv")

del_cols = ['arrive_time_index', 'arrive_time', 'direction', 'geo_hash3', 'selcte_index']
train_df.drop(del_cols, axis=1, inplace=True) 

columns = ['TRANSPORT_TRACE', 'begin_port_name', 'begin_port_position',
        'begin_port_position_hash3', 'begin_port_position_hash4',
        'begin_port_position_hash5', 'carrierName', 'end_port_name',
        'end_port_position', 'end_port_position_hash3',
        'end_port_position_hash4', 'end_port_position_hash5', 'loadingOrder',
        'vesselMMSI', 'test_index', 'geo_hash3', 'geo_hash5',
        'geo_hash4', 'speed', 'longitude',
        'latitude', 'timestamp', 'direction', 'label']

train_df.columns = columns
# Out:
#                 TRANSPORT_TRACE               arrive_time  arrive_time_index  \
# 0                   CNSHK-AEJEA  2020-02-07T17:48:03.000Z              10506
# 1                   CNSHK-AEJEA  2020-02-07T17:48:03.000Z              10506
# 2                   CNSHK-AEJEA  2020-02-07T17:48:03.000Z              10506
# 3                   CNSHK-AEJEA  2020-02-07T17:48:03.000Z              10506
# 4                   CNSHK-AEJEA  2020-02-07T17:48:03.000Z              10506
# ...                         ...                       ...                ...
# 146130  CNSHK-MYTPP-MUPLU-ZADUR  2019-11-25T06:45:05.000Z               2466
# 146131  CNSHK-MYTPP-MUPLU-ZADUR  2019-11-25T06:45:05.000Z               2466
# 146132  CNSHK-MYTPP-MUPLU-ZADUR  2019-11-25T06:45:05.000Z               2466
# 146133  CNSHK-MYTPP-MUPLU-ZADUR  2019-11-25T06:45:05.000Z               2466
# 146134  CNSHK-MYTPP-MUPLU-ZADUR  2019-11-25T06:45:05.000Z               2466
#
#        begin_port_name           begin_port_position  \
# 0                CNSHK  113.86305800000001 22.559462
# 1                CNSHK  113.86305800000001 22.559462
# 2                CNSHK  113.86305800000001 22.559462
# 3                CNSHK  113.86305800000001 22.559462
# 4                CNSHK  113.86305800000001 22.559462
# ...                ...                           ...
# 146130           CNSHK  113.86305800000001 22.559462
# 146131           CNSHK  113.86305800000001 22.559462
# 146132           CNSHK  113.86305800000001 22.559462
# 146133           CNSHK  113.86305800000001 22.559462
# 146134           CNSHK  113.86305800000001 22.559462
#
#        begin_port_position_hash3 begin_port_position_hash4  \
# 0                            ws0                      ws0b
# 1                            ws0                      ws0b
# 2                            ws0                      ws0b
# 3                            ws0                      ws0b
# 4                            ws0                      ws0b
# ...                          ...                       ...
# 146130                       ws0                      ws0b
# 146131                       ws0                      ws0b
# 146132                       ws0                      ws0b
# 146133                       ws0                      ws0b
# 146134                       ws0                      ws0b
#
#        begin_port_position_hash5 carrierName  \
# 0                          ws0br      OYSCFP
# 1                          ws0br      OYSCFP
# 2                          ws0br      OYSCFP
# 3                          ws0br      OYSCFP
# 4                          ws0br      OYSCFP
# ...                          ...         ...
# 146130                     ws0br      RWHZVZ
# 146131                     ws0br      RWHZVZ
# 146132                     ws0br      RWHZVZ
# 146133                     ws0br      RWHZVZ
# 146134                     ws0br      RWHZVZ
#
#                                                 direction  ... test_index  \
# 0       21900 21900 21900 22000 21900 21900 21900 2190...  ...        225
# 1       21900 21900 21900 22000 21900 21900 21900 2190...  ...        225
# 2       21900 21900 21900 22000 21900 21900 21900 2190...  ...        225
# 3       21900 21900 21900 22000 21900 21900 21900 2190...  ...        225
# 4       21900 21900 21900 22000 21900 21900 21900 2190...  ...        225
# ...                                                   ...  ...        ...
# 146130  22570 15490 15500 15550 15730 16520 16920 1689...  ...         -1
# 146131  22570 15490 15500 15550 15730 16520 16920 1689...  ...         -1
# 146132  22570 15490 15500 15550 15730 16520 16920 1689...  ...         -1
# 146133  22570 15490 15500 15550 15730 16520 16920 1689...  ...         -1
# 146134  22570 15490 15500 15550 15730 16520 16920 1689...  ...         -1
#
#                                          select_geo_hash3  \
# 0                 web web web web web web web web web web
# 1                 web web web web web web web web web web
# 2                 web web web web web web web web web web
# 3                 web web web web web wec wec wec wec wec
# 4                 web web web web web web wec wec wec wec
# ...                                                   ...
# 146130  w21 w21 w21 w21 w21 w21 w21 w21 w21 w21 w21 w2...
# 146131  w26 w26 w26 w26 w26 w26 w26 w26 w26 w26 w26 w2...
# 146132  w26 w26 w26 w26 w26 w26 w26 w26 w26 w26 w26 w2...
# 146133  w21 w21 w21 w21 w21 w21 w21 w21 w21 w21 w21 w2...
# 146134  w26 w26 w26 w26 w26 w26 w26 w26 w26 w26 w26 w2...
#
#                                          select_geo_hash5  \
# 0       webzx webzx webzx webzr webzr webzr webzr webz...
# 1       webzx webzx webzx webzx webzx webzx webzr webz...
# 2       webzx webzx webzx webzx webzx webzx webzr webz...
# 3       webzx webzx webzr webzr webzr wecp0 wecp1 wecp...
# 4       webzx webzx webzx webzx webzr webzr wecp0 wecp...
# ...                                                   ...
# 146130  w21wv w21wv w21wu w21wu w21wu w21wu w21wu w21w...
# 146131  w263s w263s w263k w263k w263k w263k w2635 w263...
# 146132  w263u w263s w263s w263s w263s w263h w262g w262...
# 146133  w21xs w21xs w21xs w21xs w21xs w21xs w21xs w21x...
# 146134  w263s w263u w263u w263u w263u w263u w263u w263...
#
#                                          select_geo_hash4  \
# 0       webz webz webz webz webz webz webz webz webz webz
# 1       webz webz webz webz webz webz webz webz webz webz
# 2       webz webz webz webz webz webz webz webz webz webz
# 3       webz webz webz webz webz wecp wecp wecp wecp wecp
# 4       webz webz webz webz webz webz wecp wecp wecp wecp
# ...                                                   ...
# 146130  w21w w21w w21w w21w w21w w21w w21w w21w w21w w...
# 146131  w263 w263 w263 w263 w263 w263 w263 w263 w262 w...
# 146132  w263 w263 w263 w263 w263 w263 w262 w262 w262 w...
# 146133  w21x w21x w21x w21x w21x w21x w21x w21x w21x w...
# 146134  w263 w263 w263 w263 w263 w263 w263 w263 w263 w...
#
#                                              select_speed  \
# 0                              11 10 10 7 7 9 11 15 21 22
# 1                            11 11 12 11 11 10 6 11 18 19
# 2                               12 12 13 11 11 10 9 9 7 7
# 3                             10 10 6 7 16 25 25 26 25 26
# 4                           12 12 11 10 15 21 24 25 25 25
# ...                                                   ...
# 146130  11 11 11 9 6 6 5 4 4 3 2 1 4 6 13 15 16 18 22 ...
# 146131  17 17 17 17 17 14 16 16 16 16 16 17 17 17 17 1...
# 146132  16 16 17 17 17 16 16 17 17 16 16 17 17 17 17 1...
# 146133  0 0 0 0 0 0 0 1 2 1 0 16 17 18 18 18 27 27 30 ...
# 146134  1 1 1 0 0 0 0 0 0 6 6 3 2 1 0 0 4 5 7 7 8 9 10...
#
#                                          select_longitude  \
# 0       113.88364299999999 113.885625 113.885680000000...
# 1       113.886747 113.88364299999999 113.88453 113.88...
# 2       113.88466799999999 113.883908 113.884089999999...
# 3       113.885798 113.88676699999999 113.890298 113.8...
# 4       113.88431200000001 113.88464499999999 113.8853...
# ...                                                   ...
# 146130  103.586485 103.580795 103.576993 103.571609999...
# 146131  104.60732800000001 104.607653 104.607972 104.6...
# 146132  104.60658199999999 104.606922 104.60714 104.60...
# 146133  103.550923 103.551242 103.551022 103.551052 10...
# 146134  104.630697 104.630682 104.630462 104.630457999...
#
#                                           select_latitude  \
# 0       22.437238 22.418201999999997 22.417943 22.4042...
# 1       22.442002 22.437238 22.425392000000002 22.4202...
# 2       22.439743 22.430957 22.42931 22.421452 22.4194...
# 3       22.417422 22.41245 22.396893 22.394387 22.3861...
# 4       22.439178 22.42445 22.419485 22.418733 22.3872...
# ...                                                   ...
# 146130  1.1996719999999998 1.2020680000000001 1.203977...
# 146131  1.693675 1.6826869999999998 1.666082 1.656478 ...
# 146132  1.71459 1.704838 1.699252 1.6879549999999999 1...
# 146133  1.345467 1.345508 1.345568 1.345575 1.34558 1....
# 146134  1.7134029999999998 1.713875 1.716147 1.717927 ...
#
#                                          select_timestamp  \
# 0       2020-01-24T05:38:21.000Z 2020-01-24T05:48:51.0...
# 1       2020-01-24T05:35:10.000Z 2020-01-24T05:38:21.0...
# 2       2020-01-24T05:36:49.000Z 2020-01-24T05:41:50.0...
# 3       2020-01-24T05:49:20.000Z 2020-01-24T05:52:30.0...
# 4       2020-01-24T05:37:10.000Z 2020-01-24T05:45:11.0...
# ...                                                   ...
# 146130  2019-11-09T03:54:44.000Z 2019-11-09T03:58:23.0...
# 146131  2019-11-08T19:12:32.000Z 2019-11-08T19:16:44.0...
# 146132  2019-11-08T19:04:23.000Z 2019-11-08T19:08:13.0...
# 146133  2019-11-09T20:39:48.000Z 2019-11-09T20:45:51.0...
# 146134  2019-11-08T16:06:42.000Z 2019-11-08T16:08:23.0...
#
#                                          select_direction       label
# 0       19100 16700 16700 17100 16500 16500 16600 1600...  347.458611
# 1       22000 19100 17300 17000 16900 17000 16600 1660...  347.539722
# 2       21500 17300 17400 17300 16800 16900 17100 1710...  347.648056
# 3       16600 17000 16400 16500 16000 11100 8900 8900 ...  346.785556
# 4       20900 17300 16800 16700 16000 15500 12400 1230...  346.967778
# ...                                                   ...         ...
# 146130  28830 29440 29600 29630 29600 29470 29610 2850...    5.491944
# 146131  17800 17830 18190 18720 18760 19220 20510 2051...  364.311944
# 146132  17820 17810 17780 17810 17830 19770 20560 2054...  145.005833
# 146133  35360 35360 35360 35360 35360 35360 35360 2788...  -47.602778
# 146134  35130 35170 35440 440 1180 3450 5810 9900 1019...   11.105833
#
# [146135 rows x 29 columns]
# CPU times: user 2min 21s, sys: 4.43 s, total: 2min 25s
# Wall time: 2min 25s

# %%
train_df.head(1)
# Out:
#   TRANSPORT_TRACE begin_port_name           begin_port_position  \
# 0     CNSHK-AEJEA           CNSHK  113.86305800000001 22.559462
#
#   begin_port_position_hash3 begin_port_position_hash4  \
# 0                       ws0                      ws0b
#
#   begin_port_position_hash5 carrierName end_port_name  \
# 0                     ws0br      OYSCFP         AEJEA
#
#              end_port_position end_port_position_hash3  ... test_index  \
# 0  55.04979 25.022073000000002                     thr  ...        225
#
#                                  geo_hash3  \
# 0  web web web web web web web web web web
#
#                                            geo_hash5  \
# 0  webzx webzx webzx webzr webzr webzr webzr webz...
#
#                                            geo_hash4  \
# 0  webz webz webz webz webz webz webz webz webz webz
#
#                         speed  \
# 0  11 10 10 7 7 9 11 15 21 22
#
#                                            longitude  \
# 0  113.88364299999999 113.885625 113.885680000000...
#
#                                             latitude  \
# 0  22.437238 22.418201999999997 22.417943 22.4042...
#
#                                            timestamp  \
# 0  2020-01-24T05:38:21.000Z 2020-01-24T05:48:51.0...
#
#                                            direction       label
# 0  19100 16700 16700 17100 16500 16500 16600 1600...  347.458611
#
# [1 rows x 24 columns]

# %%
test_df.head(1)
# Out:
#      loadingOrder                                          timestamp  \
# 0  AE223035353902  2019-07-03T21:16:48.000Z 2019-07-03T21:34:48.0...
#
#                                            direction  \
# 0  29070.0 34550.0 30160.0 33540.0 35140.0 35300....
#
#                                                speed TRANSPORT_TRACE  \
# 0  24 25 32 33 36 37 40 40 42 43 42 41 40 40 39 3...     CNYTN-MXZLO
#
#   carrierName   vesselMMSI                                          longitude  \
# 0      OIEQNT  C2075927370  120.09385800000001 120.035707 119.9818 119.970...
#
#                                             latitude  \
# 0  22.58132 22.617522 22.658465 22.668688 22.7568...
#
#                                            geo_hash5  ... begin_port_name  \
# 0  wsj2k wsj2e wsj2f wsj2f wsj33 wsj3c wsj7b wsj7...  ...           CNYTN
#
#   end_port_name begin_port_position               end_port_position  \
# 0         MXZLO  114.275347 22.5777  -104.305571 19.085960999999998
#
#   begin_port_position_hash4 begin_port_position_hash5  \
# 0                      ws12                     ws122
#
#   begin_port_position_hash3 end_port_position_hash4 end_port_position_hash5  \
# 0                       ws1                    9emu                   9emud
#
#   end_port_position_hash3
# 0                     9em
#
# [1 rows x 22 columns]

# %%
# %%time

def get_stats(values):   # 统计特征
    xlen = len(values)
    vmax = np.max(values)
    vmin = np.min(values)
    return [np.mean(values), vmax, vmin, np.std(values), vmax-vmin,
            np.sum(values), np.median(values), np.count_nonzero(values), len(set(values)), 
            np.count_nonzero(values)/xlen, len(set(values))/xlen, 
            # np.percentile(values, 25), np.percentile(values, 75), 
            skew(values), kurtosis(values), 
            sorted(Counter(values).items(), key=lambda x: x[1], reverse=True)[0][0]]

def feature_engineering(df, is_train=True):
    numerical_fea = []
    categorical_fea = []
    if is_train:
        label = []
    for idx in tqdm(range(df.shape[0])):
        line = df.iloc[idx]

        timestamp = [datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.000Z") for x in line['timestamp'].split(' ')]
        
        # 时间特征
        timestamp_hours = np.array([(x-timestamp[0]).total_seconds()/3600.0 for x in timestamp])  # 减去最初的时间
        timestamp_diff1 = np.diff(timestamp_hours, prepend=timestamp_hours[0])    # 时间一阶差分
        # print(timestamp_diff1[:20])
        xlen = len(timestamp_hours)   # 长度

        begin_port = [float(x) for x in line['begin_port_position'].split(' ')]
        end_port = [float(x) for x in line['end_port_position'].split(' ')]

        # 原始的四个特征
        lon = [float(x) for x in line['longitude'].split(' ')]
        lat  = [float(x) for x in line['latitude'].split(' ')]
        speed = [float(x) for x in line['speed'].split(' ')]
        direction = [float(x) for x in line['direction'].split(' ')]
        lon_diff1 = np.diff(lon, prepend=lon[0])
        lat_diff1 = np.diff(lat, prepend=lat[0])
        speed_diff1 = np.diff(speed, prepend=speed[0])
        direction_diff1 = np.diff(direction, prepend=direction[0])

        # 类别特征
        carrierName = line['carrierName']
        vesselMMSI = line['vesselMMSI']
        begin_hash3, begin_hash4, begin_hash5 = line['begin_port_position_hash3'], line['begin_port_position_hash4'], line['begin_port_position_hash5']
        end_hash3, end_hash4, end_hash5 = line['end_port_position_hash3'], line['end_port_position_hash4'], line['end_port_position_hash5']
        first_hash3, first_hash4, first_hash5 = line['geo_hash3'].split(' ')[0], line['geo_hash4'].split(' ')[0], line['geo_hash5'].split(' ')[0]
        last_hash3, last_hash4, last_hash5 = line['geo_hash3'].split(' ')[-1], line['geo_hash4'].split(' ')[-1], line['geo_hash5'].split(' ')[-1]
        first_year, first_month, first_day = timestamp[0].year, timestamp[0].month, timestamp[0].day
        last_year, last_month, last_day = timestamp[-1].year, timestamp[-1].month, timestamp[-1].day

        # 距离特征
        begin_distance = [distance(begin_port[0], begin_port[1], lon[i], lat[i]) for i in range(xlen)]  # 与起始距离
        begin_dis_cumsum = np.cumsum(begin_distance)   # 累积距离
        begin_dis_diff1 = np.diff(begin_distance, prepend=begin_distance[0])   # 一阶差分距离

        end_distance = [distance(end_port[0], end_port[1], lon[i], lat[i]) for i in range(xlen)]    # 与终止距离
        end_dis_cumsum = np.cumsum(end_distance)    # 累积距离
        end_dis_diff1 = np.diff(end_distance, prepend=end_distance[0]) 

        begin_haversine = [haversine(begin_port[0], begin_port[1], lon[i], lat[i]) for i in range(xlen)] 
        begin_hav_cumsum = np.cumsum(begin_haversine)   # 累积距离
        begin_hav_diff1 = np.diff(begin_haversine, prepend=begin_haversine[0])   # 一阶差分距离

        end_haversine = [haversine(end_port[0], end_port[1], lon[i], lat[i]) for i in range(xlen)]
        end_hav_cumsum = np.cumsum(end_haversine)   # 累积距离
        end_hav_diff1 = np.diff(end_haversine, prepend=end_haversine[0])   # 一阶差分距离

        # 速度特征
        timestamp_diff1_tmp = timestamp_diff1.copy()
        timestamp_diff1_tmp[timestamp_diff1_tmp==0] = np.mean(timestamp_diff1_tmp)
        diff_speed = begin_hav_diff1 / (timestamp_diff1_tmp + 1e-8)    # 差分路程 / 差分时间=速度
        
        timestamp_hours_tmp = timestamp_hours.copy()
        timestamp_hours_tmp[timestamp_hours_tmp == 0] = np.mean(timestamp_hours_tmp)
        cumsum_speed = begin_hav_cumsum / (timestamp_hours_tmp + 1e-8)  # 累积路程 / 累积时间

        # 简单数值特征
        speed_0_nums = (np.array(speed) == 0).sum()
        speed_0_rate = speed_0_nums / xlen 
        speed_0_time = timestamp_diff1[np.array(speed) == 0].sum()
        hash3_nunique = len(set(line['geo_hash3'].split(' ')))
        hash4_nunique = len(set(line['geo_hash4'].split(' ')))
        hash5_nunique = len(set(line['geo_hash5'].split(' ')))
        hash3_rate, hash4_rate, hash5_rate = hash3_nunique/xlen,  hash4_nunique/xlen, hash5_nunique/xlen 
        first_begin_dis, first_begin_hav = distance(begin_port[0], begin_port[1], lon[0], lat[0]), haversine(begin_port[0], begin_port[1], lon[0], lat[0])
        last_begin_dis, last_begin_hav = distance(begin_port[0], begin_port[1], lon[-1], lat[-1]), haversine(begin_port[0], begin_port[1], lon[-1], lat[-1])
        first_end_dis, first_end_hav = distance(end_port[0], end_port[1], lon[0], lat[0]), haversine(end_port[0], end_port[1], lon[0], lat[0])
        last_end_dis, last_end_hav = distance(end_port[0], end_port[1], lon[-1], lat[-1]), haversine(end_port[0], end_port[1], lon[-1], lat[-1])
        fbd_lbd, fbd_lbd_rate = last_begin_dis/first_begin_dis, last_begin_dis-first_begin_dis
        fbh_lbh, fbh_lbh_rate = last_begin_hav/first_begin_hav, last_begin_hav-first_begin_hav
        fed_led, fed_led_rate = first_end_dis/last_end_dis, first_end_dis-last_end_dis
        fed_leh, fed_leh_rate = first_end_hav/last_end_hav, first_end_hav-last_end_hav


        # 正式添加统计特征
        num_feas1 = get_stats(timestamp_hours) + get_stats(timestamp_diff1) + get_stats(lon) + get_stats(lat) + get_stats(speed) + get_stats(direction)
        num_feas2 = get_stats(begin_distance)+get_stats(begin_dis_cumsum)+get_stats(begin_dis_diff1)+get_stats(end_distance)+get_stats(end_dis_cumsum)+get_stats(end_dis_diff1)
        num_feas3 = get_stats(begin_haversine)+get_stats(begin_hav_cumsum)+get_stats(begin_hav_diff1)+get_stats(end_haversine)+get_stats(end_hav_cumsum)+get_stats(end_hav_diff1)
        num_feas4 = get_stats(diff_speed) + get_stats(cumsum_speed)
        num_feas5 = get_stats(lon_diff1) + get_stats(lat_diff1) + get_stats(speed_diff1) + get_stats(direction_diff1)
        num_feas6 = [xlen, speed_0_nums, speed_0_rate, speed_0_time, hash3_nunique, hash4_nunique, hash5_nunique, 
                     hash3_rate, hash4_rate, hash5_rate, first_begin_dis, first_begin_hav,  last_begin_dis, last_begin_hav,
                     first_end_dis, first_end_hav, last_end_dis, last_end_hav, fbd_lbd, fbd_lbd_rate, 
                     fbh_lbh, fbh_lbh_rate, fed_led, fed_led_rate, fed_leh, fed_leh_rate]
        # print(len(num_feas1+num_feas2+num_feas3))
        # break 

        # 添加类别型特征
        cat_feas1 = [carrierName, vesselMMSI, begin_hash3, begin_hash4, begin_hash5, 
                     end_hash3, end_hash4, end_hash5, first_hash3, first_hash4, first_hash5, 
                     last_hash3, last_hash4, last_hash5, first_year, first_month, first_day, 
                     last_year, last_month, last_day]
        
        numerical_fea.append(num_feas1 + num_feas2 + num_feas3 + num_feas4 + num_feas5 + num_feas6)
        categorical_fea.append(cat_feas1)
        if is_train:
            label.append(line['label'])
    
    numerical_fea = np.array(numerical_fea)
    categorical_fea = np.array(categorical_fea)
    # print(numerical_fea.shape)
    num_cols = ['num_{}'.format(str(i)) for i in range(numerical_fea.shape[1])]
    cat_cols = ['cat_{}'.format(str(i)) for i in range(categorical_fea.shape[1])]
    num_df = pd.DataFrame(numerical_fea)
    print(num_df.shape)
    cat_df = pd.DataFrame(categorical_fea)
    print(cat_df.shape)
    fea_df = pd.concat([num_df, cat_df], axis=1)
    
    fea_df.columns = num_cols + cat_cols
    if is_train:
        fea_df['label'] = label
    print(fea_df.shape)
    return fea_df

test_fea = feature_engineering(test_df, is_train=False)
train_fea = feature_engineering(train_df)
# Out:
# 100%|██████████| 228/228 [00:05<00:00, 43.97it/s]
#   0%|          | 6/146135 [00:00<40:39, 59.90it/s]
# (228, 362)
# (228, 20)
# (228, 382)
# 100%|██████████| 146135/146135 [1:36:13<00:00, 25.31it/s]
# (146135, 362)
# (146135, 20)
# (146135, 383)
# CPU times: user 1h 36min 31s, sys: 26.4 s, total: 1h 36min 57s
# Wall time: 1h 36min 29s

# %%
train_fea.to_pickle('data/train_fea.pkl')
test_fea.to_pickle('data/test_fea.pkl')

# %%
train_fea.head()
# Out:
#       num_0     num_1  num_2     num_3     num_4     num_5     num_6  num_7  \
# 0  0.424361  0.703056    0.0  0.224311  0.703056  4.243611  0.526111    9.0
# 1  0.328611  0.675000    0.0  0.237891  0.675000  3.286111  0.244722    9.0
# 2  0.242250  0.539167    0.0  0.171423  0.539167  2.422500  0.206111    9.0
# 3  0.577306  1.193056    0.0  0.399034  1.193056  5.773056  0.541389    9.0
# 4  0.574111  1.213611    0.0  0.411656  1.213611  5.741111  0.635139    9.0
#
#    num_8  num_9  num_10    num_11    num_12  num_13    num_14    num_15  \
# 0   10.0    0.9     1.0 -0.583415 -1.031987     0.0  0.070306  0.175000
# 1   10.0    0.9     1.0  0.277956 -1.377707     0.0  0.067500  0.180833
# 2   10.0    0.9     1.0  0.597904 -0.700449     0.0  0.053917  0.241944
# 3   10.0    0.9     1.0  0.064948 -1.319347     0.0  0.119306  0.255000
# 4   10.0    0.9     1.0  0.146462 -1.293110     0.0  0.121361  0.419444
#
#    num_16    num_17    num_18    num_19    num_20  num_21  num_22  num_23  \
# 0     0.0  0.068578  0.175000  0.703056  0.043056     9.0    10.0     0.9
# 1     0.0  0.058152  0.180833  0.675000  0.051667     9.0    10.0     0.9
# 2     0.0  0.069113  0.241944  0.539167  0.029167     9.0    10.0     0.9
# 3     0.0  0.082982  0.255000  1.193056  0.090694     9.0    10.0     0.9
# 4     0.0  0.141485  0.419444  1.213611  0.050556     9.0    10.0     0.9
#
#    num_24    num_25    num_26  num_27      num_28      num_29      num_30  \
# 0     1.0  0.664976 -1.296856     0.0  113.891127  113.903790  113.883643
# 1     1.0  0.717382 -0.688981     0.0  113.888163  113.895048  113.883643
# 2     1.0  1.862432  2.596480     0.0  113.886530  113.890920  113.883908
# 3     1.0  0.369298 -1.175605     0.0  113.944396  114.062595  113.885798
# 4     1.0  1.254065 -0.030471     0.0  113.919004  114.018568  113.884312
#
#      num_31    num_32       num_33      num_34  num_35  num_36  num_37  \
# 0  0.005706  0.020147  1138.911267  113.891168    10.0    10.0     1.0
# 1  0.003917  0.011405  1138.881629  113.886662    10.0    10.0     1.0
# 2  0.002437  0.007012  1138.865298  113.885726    10.0    10.0     1.0
# 3  0.063969  0.176797  1139.443958  113.913454    10.0    10.0     1.0
# 4  0.048599  0.134256  1139.190036  113.894858    10.0    10.0     1.0
#
#    num_38    num_39    num_40      num_41     num_42     num_43     num_44  \
# 0     1.0  0.794366  0.019517  113.883643  22.398996  22.437238  22.368845
# 1     1.0  0.663077 -1.084148  113.886747  22.411781  22.442002  22.382253
# 2     1.0  0.844685 -0.649900  113.884668  22.416553  22.439743  22.394583
# 3     1.0  0.673267 -1.063404  113.885798  22.376291  22.417422  22.345992
# 4     1.0  1.305314 -0.019026  113.884312  22.388259  22.439178  22.346138
#
#      num_45    num_46      num_47     num_48  num_49  num_50  num_51  num_52  \
# 0  0.019567  0.068393  223.989957  22.393654    10.0    10.0     1.0     1.0
# 1  0.020095  0.059749  224.117810  22.416631    10.0    10.0     1.0     1.0
# 2  0.014117  0.045160  224.165526  22.417687    10.0    10.0     1.0     1.0
# 3  0.026740  0.071430  223.762906  22.373155    10.0    10.0     1.0     1.0
# 4  0.033013  0.093040  223.882586  22.383119    10.0    10.0     1.0     1.0
#
#      num_53    num_54     num_55  num_56  num_57  num_58    num_59  num_60  \
# 0  0.411714 -0.646674  22.437238    12.3    22.0     7.0  5.080354    15.0
# 1 -0.105228 -1.271443  22.442002    12.0    19.0     6.0  3.605551    13.0
# 2 -0.138866 -0.930759  22.439743    10.1    13.0     7.0  1.972308     6.0
# 3  0.225159 -1.562723  22.417422    17.6    26.0     6.0  8.187796    20.0
# 4  0.138604 -1.527021  22.439178    18.0    25.0    10.0  6.212890    15.0
#
#    num_61  num_62  num_63  num_64  num_65  num_66    num_67    num_68  num_69  \
# 0   123.0    10.5    10.0     7.0     1.0     0.7  0.936854 -0.539103    11.0
# 1   120.0    11.0    10.0     6.0     1.0     0.6  0.704043 -0.033136    11.0
# 2   101.0    10.5    10.0     6.0     1.0     0.6 -0.295610 -1.111716    12.0
# 3   176.0    20.5    10.0     6.0     1.0     0.6 -0.224605 -1.745905    25.0
# 4   180.0    18.0    10.0     7.0     1.0     0.7 -0.017513 -1.808693    25.0
#
#     num_70   num_71   num_72       num_73   num_74    num_75   num_76  num_77  \
# 0  16360.0  19100.0  12900.0  1456.845908   6200.0  163600.0  16550.0    10.0
# 1  17420.0  22000.0  15600.0  1756.018223   6400.0  174200.0  16950.0    10.0
# 2  17460.0  21500.0  16600.0  1373.462777   4900.0  174600.0  17100.0    10.0
# 3  12680.0  17000.0   7000.0  3938.730760  10000.0  126800.0  13550.0    10.0
# 4  14490.0  20900.0   8500.0  3787.202134  12400.0  144900.0  15750.0    10.0
#
#    num_78  num_79  num_80    num_81    num_82   num_83    num_84    num_85  \
# 0     8.0     1.0     0.8 -0.680156  1.452750  16700.0  0.162923  0.194920
# 1     8.0     1.0     0.8  1.682256  1.869524  17000.0  0.149810  0.180073
# 2     7.0     1.0     0.7  2.474133  4.525960  17300.0  0.144827  0.167217
# 3     9.0     1.0     0.9 -0.145562 -1.794491   8900.0  0.206236  0.282015
# 4     9.0     1.0     0.9 -0.250960 -0.848522   8500.0  0.183456  0.263324
#
#      num_86    num_87    num_88    num_89    num_90  num_91  num_92  num_93  \
# 0  0.123945  0.020220  0.070975  1.629230  0.168173    10.0    10.0     1.0
# 1  0.119825  0.020397  0.060248  1.498100  0.144650    10.0    10.0     1.0
# 2  0.121654  0.014300  0.045563  1.448266  0.143576    10.0    10.0     1.0
# 3  0.143849  0.049410  0.138166  2.062363  0.197786    10.0    10.0     1.0
# 4  0.122147  0.047287  0.141177  1.834561  0.179191    10.0    10.0     1.0
#
#    num_94    num_95    num_96    num_97    num_98    num_99   num_100  \
# 0     1.0 -0.354575 -0.661659  0.123945  0.839575  1.629230  0.123945
# 1     1.0  0.138621 -1.284495  0.119825  0.766081  1.498100  0.119825
# 2     1.0  0.166850 -0.938891  0.121654  0.756183  1.448266  0.121654
# 3     1.0  0.200095 -1.528740  0.143849  0.995233  2.062363  0.143849
# 4     1.0  0.443303 -1.071131  0.122147  0.876852  1.834561  0.122147
#
#     num_101   num_102   num_103   num_104  num_105  num_106  num_107  num_108  \
# 0  0.481059  1.505284  8.395749  0.819407     10.0     10.0      1.0      1.0
# 1  0.439852  1.378275  7.660814  0.735827     10.0     10.0      1.0      1.0
# 2  0.422626  1.326613  7.561833  0.737862     10.0     10.0      1.0      1.0
# 3  0.614153  1.918514  9.952326  0.910791     10.0     10.0      1.0      1.0
# 4  0.543844  1.712414  8.768518  0.809692     10.0     10.0      1.0      1.0
#
#     num_109   num_110   num_111   num_112   num_113  num_114   num_115  \
# 0  0.117177 -1.217487  0.123945  0.007097  0.019106      0.0  0.006184
# 1  0.158811 -1.193505  0.119825  0.006025  0.011833      0.0  0.004259
# 2  0.108618 -1.205189  0.121654  0.004556  0.015159      0.0  0.004648
# 3  0.291797 -1.155655  0.143849  0.013817  0.043616      0.0  0.012087
# 4  0.306692 -1.116581  0.122147  0.014118  0.049346      0.0  0.015008
#
#     num_116   num_117   num_118  num_119  num_120  num_121  num_122   num_123  \
# 0  0.019106  0.070975  0.006781      9.0     10.0      0.9      1.0  0.472278
# 1  0.011833  0.060248  0.005775      9.0     10.0      0.9      1.0  0.127343
# 2  0.015159  0.045563  0.002839      9.0     10.0      0.9      1.0  0.993870
# 3  0.043616  0.138166  0.009914      9.0     10.0      0.9      1.0  1.268876
# 4  0.049346  0.141177  0.007216      9.0     10.0      0.9      1.0  1.253348
#
#     num_124  num_125    num_126    num_127    num_128   num_129   num_130  \
# 0 -0.974732      0.0  58.899778  58.913775  58.890607  0.006525  0.023168
# 1 -1.326413      0.0  58.896249  58.904440  58.890607  0.004732  0.013833
# 2  0.057721      0.0  58.894405  58.899765  58.891148  0.003030  0.008617
# 3  1.009301      0.0  58.954011  59.072810  58.893633  0.064835  0.179177
# 4  0.432982      0.0  58.928111  59.029425  58.891191  0.049719  0.138234
#
#       num_131    num_132  num_133  num_134  num_135  num_136   num_137  \
# 0  588.997777  58.900053     10.0     10.0      1.0      1.0  0.639501
# 1  588.962490  58.894043     10.0     10.0      1.0      1.0  0.637461
# 2  588.944045  58.893549     10.0     10.0      1.0      1.0  0.759149
# 3  589.540106  58.923435     10.0     10.0      1.0      1.0  0.650933
# 4  589.281110  58.904211     10.0     10.0      1.0      1.0  1.278590
#
#     num_138    num_139     num_140     num_141    num_142     num_143  \
# 0 -0.183323  58.890607  323.930840  588.997777  58.890607  169.178531
# 1 -1.136372  58.893499  323.917004  588.962490  58.893499  169.166566
# 2 -0.754453  58.891521  323.911057  588.944045  58.891521  169.161667
# 3 -1.096986  58.893633  324.072361  589.540106  58.893633  169.336794
# 4 -0.060082  58.891191  323.983935  589.281110  58.891191  169.250074
#
#       num_144      num_145     num_146  num_147  num_148  num_149  num_150  \
# 0  530.107170  3239.308403  323.924008     10.0     10.0      1.0      1.0
# 1  530.068991  3239.170044  323.909280     10.0     10.0      1.0      1.0
# 2  530.052524  3239.110571  323.906778     10.0     10.0      1.0      1.0
# 3  530.646472  3240.723611  323.962129     10.0     10.0      1.0      1.0
# 4  530.389920  3239.839355  323.925051     10.0     10.0      1.0      1.0
#
#     num_151   num_152    num_153   num_154   num_155   num_156   num_157  \
# 0  0.000117 -1.224226  58.890607  0.002317  0.007103  0.000000  0.002162
# 1  0.000106 -1.224221  58.893499  0.001094  0.003849 -0.002892  0.001734
# 2  0.000063 -1.224231  58.891521  0.000824  0.004284 -0.000373  0.001271
# 3  0.001417 -1.223940  58.893633  0.017918  0.047079  0.000000  0.017783
# 4  0.000936 -1.223838  58.891191  0.013823  0.088249  0.000000  0.025424
#
#     num_158   num_159   num_160  num_161  num_162  num_163  num_164   num_165  \
# 0  0.007103  0.023168  0.002074      9.0     10.0      0.9      1.0  0.835126
# 1  0.006741  0.010940  0.001187      9.0     10.0      0.9      1.0 -0.741828
# 2  0.004658  0.008243  0.000353      9.0     10.0      0.9      1.0  1.859479
# 3  0.047079  0.179177  0.011793      9.0     10.0      0.9      1.0  0.444742
# 4  0.088249  0.138234  0.004861      9.0     10.0      0.9      1.0  2.441974
#
#     num_166  num_167    num_168    num_169    num_170   num_171    num_172  \
# 0 -0.158711      0.0  18.076548  21.604948  13.754233  2.237825   7.850715
# 1  0.544593      0.0  16.623707  19.977025  13.285739  2.263171   6.691286
# 2  2.618214      0.0  16.072977  18.555868  13.495988  1.587148   5.059880
# 3 -1.445957      0.0  22.592584  30.191259  15.965986  5.131981  14.225272
# 4  4.377987      0.0  20.213491  28.525769  13.552021  5.028947  14.973748
#
#       num_173    num_174  num_175  num_176  num_177  num_178   num_179  \
# 0  180.765476  18.661805     10.0     10.0      1.0      1.0 -0.362637
# 1  166.237070  16.054867     10.0     10.0      1.0      1.0  0.133920
# 2  160.729775  15.935806     10.0     10.0      1.0      1.0  0.162876
# 3  225.925844  21.879705     10.0     10.0      1.0      1.0  0.143390
# 4  202.134914  19.879151     10.0     10.0      1.0      1.0  0.378618
#
#     num_180    num_181     num_182     num_183    num_184    num_185  \
# 0 -0.659869  13.754233   93.168990  180.765476  13.754233  53.376818
# 1 -1.282786  13.285739   85.008315  166.237070  13.285739  48.813525
# 2 -0.937811  13.495988   83.921335  160.729775  13.495988  46.905803
# 3 -1.574385  15.965986  109.809851  225.925844  15.965986  67.306547
# 4 -1.135962  13.552021   97.064720  202.134914  13.552021  59.985711
#
#       num_186      num_187     num_188  num_189  num_190  num_191  num_192  \
# 0  167.011243   931.689896   90.938382     10.0     10.0      1.0      1.0
# 1  152.951331   850.083147   81.654678     10.0     10.0      1.0      1.0
# 2  147.233787   839.213346   81.889354     10.0     10.0      1.0      1.0
# 3  209.959858  1098.098507  101.006215     10.0     10.0      1.0      1.0
# 4  188.582892   970.647200   89.851523     10.0     10.0      1.0      1.0
#
#     num_193   num_194    num_195   num_196   num_197  num_198   num_199  \
# 0  0.116748 -1.217779  13.754233  0.785071  2.123354      0.0  0.685748
# 1  0.158598 -1.193690  13.285739  0.669129  1.315997      0.0  0.472052
# 2  0.108536 -1.205266  13.495988  0.505988  1.679306      0.0  0.515695
# 3  0.274867 -1.169497  15.965986  1.422527  4.709397      0.0  1.286321
# 4  0.295246 -1.129274  13.552021  1.497375  4.947231      0.0  1.548201
#
#     num_200    num_201   num_202  num_203  num_204  num_205  num_206  \
# 0  2.123354   7.850715  0.748316      9.0     10.0      0.9      1.0
# 1  1.315997   6.691286  0.640853      9.0     10.0      0.9      1.0
# 2  1.679306   5.059880  0.314732      9.0     10.0      0.9      1.0
# 3  4.709397  14.225272  0.937347      9.0     10.0      0.9      1.0
# 4  4.947231  14.973748  0.766414      9.0     10.0      0.9      1.0
#
#     num_207   num_208  num_209      num_210      num_211      num_212  \
# 0  0.486352 -0.949392      0.0  5950.311027  5952.452782  5948.446385
# 1  0.123963 -1.320343      0.0  5949.641704  5951.191583  5948.446385
# 2  0.986162  0.032884      0.0  5949.339569  5950.419877  5948.474555
# 3  1.444406  1.514170      0.0  5956.260952  5968.454995  5949.241351
# 4  1.113183 -0.004526      0.0  5953.391466  5964.478988  5948.455827
#
#     num_213    num_214       num_215      num_216  num_217  num_218  num_219  \
# 0  1.122927   4.006396  59503.110267  5950.471700     10.0     10.0      1.0
# 1  0.954851   2.745198  59496.417037  5949.276869     10.0     10.0      1.0
# 2  0.646772   1.945322  59493.395688  5949.226403     10.0     10.0      1.0
# 3  6.968692  19.213643  59562.609522  5953.413094     10.0     10.0      1.0
# 4  5.613899  16.023161  59533.914657  5951.147312     10.0     10.0      1.0
#
#    num_220   num_221   num_222      num_223       num_224       num_225  \
# 0      1.0  0.178106 -0.587356  5948.446385  32723.567998  59503.110267
# 1      1.0  0.449436 -1.289147  5948.614434  32720.378186  59496.417037
# 2      1.0  0.476232 -0.935648  5948.474555  32719.562191  59493.395688
# 3      1.0  0.535429 -1.259204  5949.241351  32740.381758  59562.609522
# 4      1.0  1.124217 -0.286607  5948.455827  32729.356058  59533.914657
#
#        num_226       num_227       num_228        num_229       num_230  \
# 0  5948.446385  17091.460486  53554.663881  327235.679977  32722.405196
# 1  5948.614434  17089.265795  53547.802603  327203.781864  32718.872776
# 2  5948.474555  17088.372274  53544.921133  327195.621911  32718.688424
# 3  5949.241351  17109.025039  53613.368170  327403.817583  32728.322239
# 4  5948.455827  17099.482831  53585.458830  327293.560578  32722.255964
#
#    num_231  num_232  num_233  num_234   num_235   num_236      num_237  \
# 0     10.0     10.0      1.0      1.0  0.000194 -1.224231  5948.446385
# 1     10.0     10.0      1.0      1.0  0.000204 -1.224214  5948.614434
# 2     10.0     10.0      1.0      1.0  0.000128 -1.224226  5948.474555
# 3     10.0     10.0      1.0      1.0  0.001517 -1.223987  5949.241351
# 4     10.0     10.0      1.0      1.0  0.001086 -1.223859  5948.455827
#
#     num_238   num_239   num_240   num_241   num_242    num_243   num_244  \
# 0  0.400640  0.933701  0.000000  0.331239  0.933701   4.006396  0.398129
# 1  0.257715  0.662201 -0.168049  0.247542  0.830249   2.577149  0.263156
# 2  0.194532  0.793681  0.000000  0.226713  0.793681   1.945322  0.138105
# 3  1.921364  4.974976  0.000000  1.821640  4.974976  19.213643  1.364446
# 4  1.602316  9.080791  0.000000  2.583937  9.080791  16.023161  0.629763
#
#    num_245  num_246  num_247  num_248   num_249   num_250  num_251    num_252  \
# 0      9.0     10.0      0.9      1.0  0.139539 -1.567365      0.0  11.103698
# 1      9.0     10.0      0.9      1.0 -0.077384 -1.021338      0.0  10.385690
# 2      9.0     10.0      0.9      1.0  1.672290  2.042603      0.0   9.437115
# 3      9.0     10.0      0.9      1.0  0.538360 -1.304986      0.0  10.056052
# 4      9.0     10.0      0.9      1.0  2.344118  4.061461      0.0  12.403801
#
#      num_253  num_254   num_255    num_256     num_257    num_258  num_259  \
# 0  20.091522      0.0  5.477718  20.091522  111.036980  11.036105      9.0
# 1  19.353773      0.0  4.819666  19.353773  103.856899  10.381589      9.0
# 2  13.240124      0.0  3.595419  13.240124   94.371150  10.487301      9.0
# 3  18.468222      0.0  4.499539  18.468222  100.560518  10.886431      9.0
# 4  18.745322      0.0  5.268351  18.745322  124.038008  12.174158      9.0
#
#    num_260  num_261  num_262   num_263   num_264  num_265     num_266  \
# 0     10.0      0.9      1.0 -0.194659 -0.168979      0.0  194.010006
# 1     10.0      0.9      1.0 -0.309005  0.454782      0.0  269.090439
# 2     10.0      0.9      1.0 -1.622458  1.972446      0.0  331.743283
# 3     10.0      0.9      1.0 -0.470609  0.761919      0.0  213.023470
# 4     10.0      0.9      1.0 -0.922095  0.582302      0.0  173.851806
#
#       num_267    num_268     num_269     num_270      num_271     num_272  \
# 0  257.114067  32.411624   63.933165  224.702443  1940.100055  200.378354
# 1  509.653828  40.429973  112.456059  469.223854  2690.904388  257.568431
# 2  436.691246  55.710990  105.124463  380.980255  3317.432831  357.033212
# 3  615.665554  27.656041  143.008201  588.009514  2130.234701  182.059357
# 4  319.112971  23.605224   73.393805  295.507747  1738.518065  162.100591
#
#    num_273  num_274  num_275  num_276   num_277   num_278    num_279  \
# 0     10.0     10.0      1.0      1.0 -1.364979  1.343228  32.411624
# 1     10.0     10.0      1.0      1.0  0.157187  0.845341  40.429973
# 2     10.0     10.0      1.0      1.0 -1.629544  1.950204  55.710990
# 3     10.0     10.0      1.0      1.0  2.003491  3.569208  27.656041
# 4     10.0     10.0      1.0      1.0 -0.000200  0.405613  23.605224
#
#     num_280   num_281   num_282   num_283   num_284   num_285   num_286  \
# 0  0.002015  0.006698  0.000000  0.002005  0.006698  0.020147  0.001577
# 1  0.000830  0.003352 -0.003104  0.001634  0.006456  0.008301  0.000879
# 2  0.000625  0.003631 -0.000760  0.001121  0.004391  0.006252  0.000273
# 3  0.017680  0.047399  0.000000  0.017747  0.047399  0.176797  0.011460
# 4  0.013426  0.087758  0.000000  0.025361  0.087758  0.134256  0.004601
#
#    num_287  num_288  num_289  num_290   num_291   num_292  num_293   num_294  \
# 0      9.0     10.0      0.9      1.0  1.086230  0.345334      0.0 -0.006839
# 1      9.0     10.0      0.9      1.0 -0.944350  1.020347      0.0 -0.005975
# 2      9.0     10.0      0.9      1.0  1.695399  2.434424      0.0 -0.004516
# 3      9.0     10.0      0.9      1.0  0.439594 -1.437563      0.0 -0.005725
# 4      9.0     10.0      0.9      1.0  2.452751  4.412462      0.0 -0.009222
#
#     num_295   num_296   num_297   num_298   num_299   num_300  num_301  \
# 0  0.000000 -0.019036  0.006072  0.019036 -0.068393 -0.006362      9.0
# 1  0.000000 -0.011846  0.004171  0.011846 -0.059749 -0.005693      9.0
# 2  0.000000 -0.014765  0.004580  0.014765 -0.045160 -0.002782      9.0
# 3  0.008168 -0.034705  0.011618  0.042873 -0.057252 -0.003739      9.0
# 4  0.000824 -0.031436  0.009487  0.032260 -0.092216 -0.006661      9.0
#
#    num_302  num_303  num_304   num_305   num_306  num_307  num_308  num_309  \
# 0     10.0      0.9      1.0 -0.574443 -0.792865      0.0      1.1      6.0
# 1     10.0      0.9      1.0 -0.101834 -1.286014      0.0      0.8      7.0
# 2     10.0      0.9      1.0 -0.941225 -0.113156      0.0     -0.5      1.0
# 3     10.0      0.9      1.0 -1.313789  1.242433      0.0      1.6      9.0
# 4     10.0      0.9      1.0 -1.040942  0.350687      0.0      1.3      6.0
#
#    num_310   num_311  num_312  num_313  num_314  num_315  num_316  num_317  \
# 0     -3.0  2.426932      9.0     11.0      0.5      7.0      7.0      0.7
# 1     -4.0  2.959730     11.0      8.0      0.0      7.0      6.0      0.7
# 2     -2.0  0.921954      3.0     -5.0      0.0      5.0      4.0      0.5
# 3     -4.0  3.954744     13.0     16.0      0.5      7.0      5.0      0.7
# 4     -1.0  2.368544      7.0     13.0      0.0      6.0      6.0      0.6
#
#    num_318   num_319   num_320  num_321  num_322  num_323  num_324  \
# 0      0.7  0.428972 -0.247393      0.0   -620.0    400.0  -2600.0
# 1      0.6  0.727575  0.051792      0.0   -640.0    100.0  -2900.0
# 2      0.4 -0.382818 -0.837370      0.0   -490.0    200.0  -4200.0
# 3      0.5  0.977039 -0.119282      0.0   -820.0   1400.0  -4900.0
# 4      0.6  0.950064 -0.613324      0.0  -1240.0      0.0  -3800.0
#
#        num_325  num_326  num_327  num_328  num_329  num_330  num_331  num_332  \
# 0   990.757286   3000.0  -6200.0   -250.0      7.0      7.0      0.7      0.7
# 1   912.359578   3000.0  -6400.0   -350.0      8.0      8.0      0.8      0.8
# 2  1257.338459   4400.0  -4900.0      0.0      7.0      6.0      0.7      0.6
# 3  1687.483333   6300.0  -8200.0   -250.0      8.0      9.0      0.8      0.9
# 4  1504.792344   3800.0 -12400.0   -500.0      8.0      7.0      0.8      0.7
#
#     num_333   num_334  num_335  num_336  num_337  num_338  num_339  num_340  \
# 0 -1.156879 -0.176764      0.0     10.0      0.0      0.0      0.0      1.0
# 1 -1.574628  1.132852      0.0     10.0      0.0      0.0      0.0      1.0
# 2 -2.511074  4.606920      0.0     10.0      0.0      0.0      0.0      1.0
# 3 -1.188763  0.825804      0.0     10.0      0.0      0.0      0.0      2.0
# 4 -0.839691 -1.152512      0.0     10.0      0.0      0.0      0.0      2.0
#
#    num_341  num_342  num_343  num_344  num_345   num_346    num_347   num_348  \
# 0      1.0      2.0      0.1      0.1      0.2  0.123945  13.754233  0.194920
# 1      1.0      2.0      0.1      0.1      0.2  0.119825  13.285739  0.180073
# 2      1.0      2.0      0.1      0.1      0.2  0.121654  13.495988  0.167217
# 3      2.0      5.0      0.2      0.2      0.5  0.143849  15.965986  0.282015
# 4      2.0      4.0      0.2      0.2      0.4  0.122147  13.552021  0.263324
#
#      num_349    num_350      num_351    num_352      num_353   num_354  \
# 0  21.604948  58.890607  5948.446385  58.913775  5952.452782  1.572631
# 1  19.977025  58.893499  5948.614434  58.904440  5951.191583  1.502803
# 2  18.555868  58.891521  5948.474555  58.899765  5950.419877  1.374529
# 3  30.191259  58.893633  5949.241351  59.072810  5968.454995  1.960495
# 4  28.525769  58.891191  5948.455827  59.029425  5964.478988  2.155791
#
#     num_355   num_356    num_357   num_358   num_359   num_360    num_361  \
# 0  0.070975  1.570785   7.850715  0.999607 -0.023168  0.999327  -4.006396
# 1  0.060248  1.503644   6.691286  0.999814 -0.010940  0.999567  -2.577149
# 2  0.045563  1.374917   5.059880  0.999860 -0.008243  0.999673  -1.945322
# 3  0.138166  1.890974  14.225272  0.996967 -0.179177  0.996781 -19.213643
# 4  0.141177  2.104909  14.973748  0.997658 -0.138234  0.997314 -16.023161
#
#     cat_0        cat_1 cat_2 cat_3  cat_4 cat_5 cat_6  cat_7 cat_8 cat_9  \
# 0  OYSCFP  Z9282756147   ws0  ws0b  ws0br   thr  thrn  thrnk   web  webz
# 1  OYSCFP  Z9282756147   ws0  ws0b  ws0br   thr  thrn  thrnk   web  webz
# 2  OYSCFP  Z9282756147   ws0  ws0b  ws0br   thr  thrn  thrnk   web  webz
# 3  OYSCFP  Z9282756147   ws0  ws0b  ws0br   thr  thrn  thrnk   web  webz
# 4  OYSCFP  Z9282756147   ws0  ws0b  ws0br   thr  thrn  thrnk   web  webz
#
#   cat_10 cat_11 cat_12 cat_13 cat_14 cat_15 cat_16 cat_17 cat_18 cat_19  \
# 0  webzx    web   webz  webzr   2020      1     24   2020      1     24
# 1  webzx    web   webz  webzr   2020      1     24   2020      1     24
# 2  webzx    web   webz  webzr   2020      1     24   2020      1     24
# 3  webzx    wec   wecp  wecp5   2020      1     24   2020      1     24
# 4  webzx    wec   wecp  wecp4   2020      1     24   2020      1     24
#
#         label
# 0  347.458611
# 1  347.539722
# 2  347.648056
# 3  346.785556
# 4  346.967778

# %%
use_cols = []
# imp = pd.read_pickle("imp.pkl")
# del_cols = imp['feat'].values.tolist()[-50:]

for col in ['num_{}'.format(str(i)) for i in range(362)]:
    if np.std(train_fea[col].values) > 0.01:
        use_cols.append(col)
print(len(use_cols))
# Out:
# 338

# %%
# label_encoder
from sklearn.preprocessing import LabelEncoder

test_fea['label'] = -1e8
data_fea = pd.concat([train_fea, test_fea])
data_fea = data_fea.reset_index(drop=True)

for col in ['cat_{}'.format(str(i)) for i in range(20)]:
    print(col)
    le = LabelEncoder()
    data_fea[col] = le.fit_transform(data_fea[col])
    data_fea[col] = data_fea[col].astype('category')

train_feas = data_fea[data_fea['label'] != -1e8].reset_index(drop=True)
test_feas = data_fea[data_fea['label'] == -1e8].reset_index(drop=True)
del test_feas['label']
print(train_feas.shape, test_feas.shape)

all_feas = use_cols + ['cat_{}'.format(str(i)) for i in range(20)]
cat_feas = ['cat_{}'.format(str(i)) for i in range(20)]
print(len(all_feas), len(cat_feas))
# Out:
# cat_0
# cat_1
# cat_2
# cat_3
# cat_4
# cat_5
# cat_6
# cat_7
# cat_8
# cat_9
# cat_10
# cat_11
# cat_12
# cat_13
# cat_14
# cat_15
# cat_16
# cat_17
# cat_18
# cat_19
# (146135, 383) (228, 382)
# 358 20

# %%
from sklearn.metrics import mean_squared_error as mse 
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.model_selection import GroupKFold

# %%
# !pip install lightgbm

# %%
def mse_score_eval(preds, valid):
    labels = valid.get_label()
    scores = mse(y_true=labels, y_pred=preds)
    return 'mse_score', scores, False

def build_model(train, test, label, seed=2020, is_shuffle=True):
    imp = pd.DataFrame()  # 特征重要性
    imp['feat'] = all_feas

    train_pred = np.zeros((train.shape[0], ))
    test_pred = np.zeros((test.shape[0], ))
    n_splits = 10
    # Kfold
    # fold = GroupKFold(n_splits=n_splits)
    fold = KFold(n_splits=n_splits, shuffle=is_shuffle, random_state=seed)
    # groups = train_df['loadingOrder'].values
    kf_way = fold.split(train)
    # params
    params = {
        'learning_rate': 0.05,
        'boosting_type': 'gbdt',
        'objective': 'regression',
        'num_leaves': 128,
        'feature_fraction': 0.85,
        'bagging_fraction': 0.75,
        'bagging_freq': 5,
        'seed': 8,
        'bagging_seed': 1,
        'feature_fraction_seed': 7,
        'min_data_in_leaf': 20,
        'nthread': -1,
        'verbose': 1,
    }
    # train
    for n_fold, (train_idx, valid_idx) in enumerate(kf_way, start=1):
        print("fold ", n_fold)
        train_x, train_y = train.iloc[train_idx], label[train_idx]
        valid_x, valid_y = train.iloc[valid_idx], label[valid_idx]
        # 数据加载
        n_train = lgb.Dataset(train_x, label=train_y)
        n_valid = lgb.Dataset(valid_x, label=valid_y)

        clf = lgb.train(
            params=params,
            train_set=n_train,
            categorical_feature=cat_feas,
            num_boost_round=10000,
            valid_sets=[n_train, n_valid],
            early_stopping_rounds=50,
            verbose_eval=100,
            feval=mse_score_eval
        )
        train_pred[valid_idx] = clf.predict(valid_x, num_iteration=clf.best_iteration)
        test_pred += clf.predict(test, num_iteration=clf.best_iteration)/fold.n_splits

        imp['gain' + str(n_fold + 1)] = clf.feature_importance(importance_type='gain')
        imp['split' + str(n_fold + 1)] = clf.feature_importance(importance_type='split')

    print("train mse: ", mse(label, train_pred))
    result = pd.DataFrame({
        'loadingOrder': test_df['loadingOrder'], 
        'label': test_pred,
    })
    return result, imp

result, imp = build_model(train_feas[all_feas], test_feas[all_feas], train_feas['label'].values, is_shuffle=True)
# Out:
# fold  1
# /opt/conda/envs/python3/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_0', 'cat_1', 'cat_10', 'cat_11', 'cat_12', 'cat_13', 'cat_14', 'cat_15', 'cat_16', 'cat_17', 'cat_18', 'cat_19', 'cat_2', 'cat_3', 'cat_4', 'cat_5', 'cat_6', 'cat_7', 'cat_8', 'cat_9']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 345.008	training's mse_score: 345.008	valid_1's l2: 741.237	valid_1's mse_score: 741.237
# [200]	training's l2: 129.463	training's mse_score: 129.463	valid_1's l2: 509.409	valid_1's mse_score: 509.409
# [300]	training's l2: 72.1607	training's mse_score: 72.1607	valid_1's l2: 445.352	valid_1's mse_score: 445.352
# [400]	training's l2: 45.6524	training's mse_score: 45.6524	valid_1's l2: 413.386	valid_1's mse_score: 413.386
# [500]	training's l2: 30.953	training's mse_score: 30.953	valid_1's l2: 394.182	valid_1's mse_score: 394.182
# [600]	training's l2: 21.9024	training's mse_score: 21.9024	valid_1's l2: 381.571	valid_1's mse_score: 381.571
# [700]	training's l2: 16.2897	training's mse_score: 16.2897	valid_1's l2: 373.756	valid_1's mse_score: 373.756
# [800]	training's l2: 12.3894	training's mse_score: 12.3894	valid_1's l2: 368.148	valid_1's mse_score: 368.148
# [900]	training's l2: 9.70774	training's mse_score: 9.70774	valid_1's l2: 364.218	valid_1's mse_score: 364.218
# [1000]	training's l2: 7.72334	training's mse_score: 7.72334	valid_1's l2: 361.23	valid_1's mse_score: 361.23
# [1100]	training's l2: 6.25332	training's mse_score: 6.25332	valid_1's l2: 359.101	valid_1's mse_score: 359.101
# [1200]	training's l2: 5.1943	training's mse_score: 5.1943	valid_1's l2: 357.487	valid_1's mse_score: 357.487
# [1300]	training's l2: 4.36348	training's mse_score: 4.36348	valid_1's l2: 356.064	valid_1's mse_score: 356.064
# [1400]	training's l2: 3.7139	training's mse_score: 3.7139	valid_1's l2: 354.929	valid_1's mse_score: 354.929
# [1500]	training's l2: 3.10237	training's mse_score: 3.10237	valid_1's l2: 353.893	valid_1's mse_score: 353.893
# [1600]	training's l2: 2.57821	training's mse_score: 2.57821	valid_1's l2: 353.19	valid_1's mse_score: 353.19
# [1700]	training's l2: 2.17422	training's mse_score: 2.17422	valid_1's l2: 352.423	valid_1's mse_score: 352.423
# [1800]	training's l2: 1.85063	training's mse_score: 1.85063	valid_1's l2: 351.916	valid_1's mse_score: 351.916
# [1900]	training's l2: 1.58169	training's mse_score: 1.58169	valid_1's l2: 351.394	valid_1's mse_score: 351.394
# [2000]	training's l2: 1.35062	training's mse_score: 1.35062	valid_1's l2: 351.002	valid_1's mse_score: 351.002
# [2100]	training's l2: 1.17835	training's mse_score: 1.17835	valid_1's l2: 350.569	valid_1's mse_score: 350.569
# [2200]	training's l2: 1.03225	training's mse_score: 1.03225	valid_1's l2: 350.307	valid_1's mse_score: 350.307
# [2300]	training's l2: 0.903212	training's mse_score: 0.903212	valid_1's l2: 350.044	valid_1's mse_score: 350.044
# [2400]	training's l2: 0.800474	training's mse_score: 0.800474	valid_1's l2: 349.872	valid_1's mse_score: 349.872
# [2500]	training's l2: 0.71356	training's mse_score: 0.71356	valid_1's l2: 349.692	valid_1's mse_score: 349.692
# [2600]	training's l2: 0.636073	training's mse_score: 0.636073	valid_1's l2: 349.516	valid_1's mse_score: 349.516
# [2700]	training's l2: 0.568274	training's mse_score: 0.568274	valid_1's l2: 349.334	valid_1's mse_score: 349.334
# [2800]	training's l2: 0.51242	training's mse_score: 0.51242	valid_1's l2: 349.216	valid_1's mse_score: 349.216
# [2900]	training's l2: 0.462292	training's mse_score: 0.462292	valid_1's l2: 349.115	valid_1's mse_score: 349.115
# [3000]	training's l2: 0.419105	training's mse_score: 0.419105	valid_1's l2: 349.051	valid_1's mse_score: 349.051
# [3100]	training's l2: 0.380562	training's mse_score: 0.380562	valid_1's l2: 348.95	valid_1's mse_score: 348.95
# [3200]	training's l2: 0.34583	training's mse_score: 0.34583	valid_1's l2: 348.866	valid_1's mse_score: 348.866
# [3300]	training's l2: 0.316311	training's mse_score: 0.316311	valid_1's l2: 348.771	valid_1's mse_score: 348.771
# [3400]	training's l2: 0.288751	training's mse_score: 0.288751	valid_1's l2: 348.717	valid_1's mse_score: 348.717
# [3500]	training's l2: 0.265953	training's mse_score: 0.265953	valid_1's l2: 348.673	valid_1's mse_score: 348.673
# [3600]	training's l2: 0.244988	training's mse_score: 0.244988	valid_1's l2: 348.631	valid_1's mse_score: 348.631
# [3700]	training's l2: 0.226718	training's mse_score: 0.226718	valid_1's l2: 348.592	valid_1's mse_score: 348.592
# [3800]	training's l2: 0.209523	training's mse_score: 0.209523	valid_1's l2: 348.543	valid_1's mse_score: 348.543
# [3900]	training's l2: 0.194501	training's mse_score: 0.194501	valid_1's l2: 348.488	valid_1's mse_score: 348.488
# [4000]	training's l2: 0.180818	training's mse_score: 0.180818	valid_1's l2: 348.466	valid_1's mse_score: 348.466
# [4100]	training's l2: 0.168122	training's mse_score: 0.168122	valid_1's l2: 348.416	valid_1's mse_score: 348.416
# [4200]	training's l2: 0.156911	training's mse_score: 0.156911	valid_1's l2: 348.387	valid_1's mse_score: 348.387
# [4300]	training's l2: 0.147024	training's mse_score: 0.147024	valid_1's l2: 348.35	valid_1's mse_score: 348.35
# [4400]	training's l2: 0.137545	training's mse_score: 0.137545	valid_1's l2: 348.336	valid_1's mse_score: 348.336
# [4500]	training's l2: 0.12935	training's mse_score: 0.12935	valid_1's l2: 348.302	valid_1's mse_score: 348.302
# [4600]	training's l2: 0.121836	training's mse_score: 0.121836	valid_1's l2: 348.282	valid_1's mse_score: 348.282
# [4700]	training's l2: 0.115026	training's mse_score: 0.115026	valid_1's l2: 348.259	valid_1's mse_score: 348.259
# [4800]	training's l2: 0.108613	training's mse_score: 0.108613	valid_1's l2: 348.239	valid_1's mse_score: 348.239
# [4900]	training's l2: 0.103025	training's mse_score: 0.103025	valid_1's l2: 348.226	valid_1's mse_score: 348.226
# [5000]	training's l2: 0.097366	training's mse_score: 0.097366	valid_1's l2: 348.213	valid_1's mse_score: 348.213
# Early stopping, best iteration is:
# [5008]	training's l2: 0.0969281	training's mse_score: 0.0969281	valid_1's l2: 348.21	valid_1's mse_score: 348.21
# fold  2
# /opt/conda/envs/python3/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_0', 'cat_1', 'cat_10', 'cat_11', 'cat_12', 'cat_13', 'cat_14', 'cat_15', 'cat_16', 'cat_17', 'cat_18', 'cat_19', 'cat_2', 'cat_3', 'cat_4', 'cat_5', 'cat_6', 'cat_7', 'cat_8', 'cat_9']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 343.027	training's mse_score: 343.027	valid_1's l2: 636.608	valid_1's mse_score: 636.608
# [200]	training's l2: 127.677	training's mse_score: 127.677	valid_1's l2: 429.565	valid_1's mse_score: 429.565
# [300]	training's l2: 70.2632	training's mse_score: 70.2632	valid_1's l2: 369.95	valid_1's mse_score: 369.95
# [400]	training's l2: 44.3122	training's mse_score: 44.3122	valid_1's l2: 340.874	valid_1's mse_score: 340.874
# [500]	training's l2: 30.3029	training's mse_score: 30.3029	valid_1's l2: 322.832	valid_1's mse_score: 322.832
# [600]	training's l2: 21.4444	training's mse_score: 21.4444	valid_1's l2: 310.887	valid_1's mse_score: 310.887
# [700]	training's l2: 15.9209	training's mse_score: 15.9209	valid_1's l2: 302.568	valid_1's mse_score: 302.568
# [800]	training's l2: 11.9572	training's mse_score: 11.9572	valid_1's l2: 296.47	valid_1's mse_score: 296.47
# [900]	training's l2: 9.23305	training's mse_score: 9.23305	valid_1's l2: 292.235	valid_1's mse_score: 292.235
# [1000]	training's l2: 7.29702	training's mse_score: 7.29702	valid_1's l2: 289.079	valid_1's mse_score: 289.079
# [1100]	training's l2: 5.88639	training's mse_score: 5.88639	valid_1's l2: 286.761	valid_1's mse_score: 286.761
# [1200]	training's l2: 4.80359	training's mse_score: 4.80359	valid_1's l2: 284.881	valid_1's mse_score: 284.881
# [1300]	training's l2: 3.95581	training's mse_score: 3.95581	valid_1's l2: 283.456	valid_1's mse_score: 283.456
# [1400]	training's l2: 3.29694	training's mse_score: 3.29694	valid_1's l2: 282.294	valid_1's mse_score: 282.294
# [1500]	training's l2: 2.76818	training's mse_score: 2.76818	valid_1's l2: 281.224	valid_1's mse_score: 281.224
# [1600]	training's l2: 2.35715	training's mse_score: 2.35715	valid_1's l2: 280.457	valid_1's mse_score: 280.457
# [1700]	training's l2: 2.0245	training's mse_score: 2.0245	valid_1's l2: 279.767	valid_1's mse_score: 279.767
# [1800]	training's l2: 1.75729	training's mse_score: 1.75729	valid_1's l2: 279.149	valid_1's mse_score: 279.149
# [1900]	training's l2: 1.51852	training's mse_score: 1.51852	valid_1's l2: 278.561	valid_1's mse_score: 278.561
# [2000]	training's l2: 1.32898	training's mse_score: 1.32898	valid_1's l2: 278.202	valid_1's mse_score: 278.202
# [2100]	training's l2: 1.16553	training's mse_score: 1.16553	valid_1's l2: 277.742	valid_1's mse_score: 277.742
# [2200]	training's l2: 1.02685	training's mse_score: 1.02685	valid_1's l2: 277.435	valid_1's mse_score: 277.435
# [2300]	training's l2: 0.910969	training's mse_score: 0.910969	valid_1's l2: 277.167	valid_1's mse_score: 277.167
# [2400]	training's l2: 0.812473	training's mse_score: 0.812473	valid_1's l2: 276.924	valid_1's mse_score: 276.924
# [2500]	training's l2: 0.724288	training's mse_score: 0.724288	valid_1's l2: 276.729	valid_1's mse_score: 276.729
# [2600]	training's l2: 0.653054	training's mse_score: 0.653054	valid_1's l2: 276.529	valid_1's mse_score: 276.529
# [2700]	training's l2: 0.58912	training's mse_score: 0.58912	valid_1's l2: 276.391	valid_1's mse_score: 276.391
# [2800]	training's l2: 0.533662	training's mse_score: 0.533662	valid_1's l2: 276.235	valid_1's mse_score: 276.235
# [2900]	training's l2: 0.484221	training's mse_score: 0.484221	valid_1's l2: 276.088	valid_1's mse_score: 276.088
# [3000]	training's l2: 0.442158	training's mse_score: 0.442158	valid_1's l2: 275.967	valid_1's mse_score: 275.967
# [3100]	training's l2: 0.402846	training's mse_score: 0.402846	valid_1's l2: 275.854	valid_1's mse_score: 275.854
# [3200]	training's l2: 0.370206	training's mse_score: 0.370206	valid_1's l2: 275.765	valid_1's mse_score: 275.765
# [3300]	training's l2: 0.340675	training's mse_score: 0.340675	valid_1's l2: 275.662	valid_1's mse_score: 275.662
# [3400]	training's l2: 0.314075	training's mse_score: 0.314075	valid_1's l2: 275.586	valid_1's mse_score: 275.586
# [3500]	training's l2: 0.292087	training's mse_score: 0.292087	valid_1's l2: 275.531	valid_1's mse_score: 275.531
# [3600]	training's l2: 0.271611	training's mse_score: 0.271611	valid_1's l2: 275.47	valid_1's mse_score: 275.47
# [3700]	training's l2: 0.253461	training's mse_score: 0.253461	valid_1's l2: 275.409	valid_1's mse_score: 275.409
# [3800]	training's l2: 0.236353	training's mse_score: 0.236353	valid_1's l2: 275.351	valid_1's mse_score: 275.351
# [3900]	training's l2: 0.221006	training's mse_score: 0.221006	valid_1's l2: 275.31	valid_1's mse_score: 275.31
# [4000]	training's l2: 0.206695	training's mse_score: 0.206695	valid_1's l2: 275.261	valid_1's mse_score: 275.261
# [4100]	training's l2: 0.194479	training's mse_score: 0.194479	valid_1's l2: 275.226	valid_1's mse_score: 275.226
# [4200]	training's l2: 0.183782	training's mse_score: 0.183782	valid_1's l2: 275.193	valid_1's mse_score: 275.193
# [4300]	training's l2: 0.173422	training's mse_score: 0.173422	valid_1's l2: 275.167	valid_1's mse_score: 275.167
# [4400]	training's l2: 0.162477	training's mse_score: 0.162477	valid_1's l2: 275.158	valid_1's mse_score: 275.158
# [4500]	training's l2: 0.152002	training's mse_score: 0.152002	valid_1's l2: 275.131	valid_1's mse_score: 275.131
# [4600]	training's l2: 0.14282	training's mse_score: 0.14282	valid_1's l2: 275.094	valid_1's mse_score: 275.094
# [4700]	training's l2: 0.135115	training's mse_score: 0.135115	valid_1's l2: 275.068	valid_1's mse_score: 275.068
# [4800]	training's l2: 0.128024	training's mse_score: 0.128024	valid_1's l2: 275.031	valid_1's mse_score: 275.031
# [4900]	training's l2: 0.121991	training's mse_score: 0.121991	valid_1's l2: 275.028	valid_1's mse_score: 275.028
# Early stopping, best iteration is:
# [4850]	training's l2: 0.124905	training's mse_score: 0.124905	valid_1's l2: 275.018	valid_1's mse_score: 275.018
# fold  3
# /opt/conda/envs/python3/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_0', 'cat_1', 'cat_10', 'cat_11', 'cat_12', 'cat_13', 'cat_14', 'cat_15', 'cat_16', 'cat_17', 'cat_18', 'cat_19', 'cat_2', 'cat_3', 'cat_4', 'cat_5', 'cat_6', 'cat_7', 'cat_8', 'cat_9']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 339.876	training's mse_score: 339.876	valid_1's l2: 558.776	valid_1's mse_score: 558.776
# [200]	training's l2: 126.162	training's mse_score: 126.162	valid_1's l2: 380.524	valid_1's mse_score: 380.524
# [300]	training's l2: 70.0654	training's mse_score: 70.0654	valid_1's l2: 332.33	valid_1's mse_score: 332.33
# [400]	training's l2: 44.0111	training's mse_score: 44.0111	valid_1's l2: 306.332	valid_1's mse_score: 306.332
# [500]	training's l2: 29.6406	training's mse_score: 29.6406	valid_1's l2: 289.853	valid_1's mse_score: 289.853
# [600]	training's l2: 20.9211	training's mse_score: 20.9211	valid_1's l2: 279.836	valid_1's mse_score: 279.836
# [700]	training's l2: 15.3597	training's mse_score: 15.3597	valid_1's l2: 273.34	valid_1's mse_score: 273.34
# [800]	training's l2: 11.5019	training's mse_score: 11.5019	valid_1's l2: 267.978	valid_1's mse_score: 267.978
# [900]	training's l2: 8.93244	training's mse_score: 8.93244	valid_1's l2: 264.117	valid_1's mse_score: 264.117
# [1000]	training's l2: 7.03995	training's mse_score: 7.03995	valid_1's l2: 261.333	valid_1's mse_score: 261.333
# [1100]	training's l2: 5.6814	training's mse_score: 5.6814	valid_1's l2: 259.13	valid_1's mse_score: 259.13
# [1200]	training's l2: 4.64001	training's mse_score: 4.64001	valid_1's l2: 257.359	valid_1's mse_score: 257.359
# [1300]	training's l2: 3.81231	training's mse_score: 3.81231	valid_1's l2: 255.956	valid_1's mse_score: 255.956
# [1400]	training's l2: 3.18632	training's mse_score: 3.18632	valid_1's l2: 254.896	valid_1's mse_score: 254.896
# [1500]	training's l2: 2.64645	training's mse_score: 2.64645	valid_1's l2: 253.954	valid_1's mse_score: 253.954
# [1600]	training's l2: 2.23519	training's mse_score: 2.23519	valid_1's l2: 253.2	valid_1's mse_score: 253.2
# [1700]	training's l2: 1.90954	training's mse_score: 1.90954	valid_1's l2: 252.642	valid_1's mse_score: 252.642
# [1800]	training's l2: 1.64681	training's mse_score: 1.64681	valid_1's l2: 252.275	valid_1's mse_score: 252.275
# [1900]	training's l2: 1.42805	training's mse_score: 1.42805	valid_1's l2: 251.805	valid_1's mse_score: 251.805
# [2000]	training's l2: 1.24609	training's mse_score: 1.24609	valid_1's l2: 251.466	valid_1's mse_score: 251.466
# [2100]	training's l2: 1.09578	training's mse_score: 1.09578	valid_1's l2: 251.148	valid_1's mse_score: 251.148
# [2200]	training's l2: 0.961956	training's mse_score: 0.961956	valid_1's l2: 250.77	valid_1's mse_score: 250.77
# [2300]	training's l2: 0.849593	training's mse_score: 0.849593	valid_1's l2: 250.512	valid_1's mse_score: 250.512
# [2400]	training's l2: 0.756966	training's mse_score: 0.756966	valid_1's l2: 250.346	valid_1's mse_score: 250.346
# [2500]	training's l2: 0.6753	training's mse_score: 0.6753	valid_1's l2: 250.209	valid_1's mse_score: 250.209
# [2600]	training's l2: 0.606268	training's mse_score: 0.606268	valid_1's l2: 250.069	valid_1's mse_score: 250.069
# [2700]	training's l2: 0.545959	training's mse_score: 0.545959	valid_1's l2: 249.938	valid_1's mse_score: 249.938
# [2800]	training's l2: 0.494897	training's mse_score: 0.494897	valid_1's l2: 249.797	valid_1's mse_score: 249.797
# [2900]	training's l2: 0.447125	training's mse_score: 0.447125	valid_1's l2: 249.708	valid_1's mse_score: 249.708
# [3000]	training's l2: 0.401803	training's mse_score: 0.401803	valid_1's l2: 249.593	valid_1's mse_score: 249.593
# [3100]	training's l2: 0.36382	training's mse_score: 0.36382	valid_1's l2: 249.537	valid_1's mse_score: 249.537
# [3200]	training's l2: 0.330788	training's mse_score: 0.330788	valid_1's l2: 249.465	valid_1's mse_score: 249.465
# [3300]	training's l2: 0.30234	training's mse_score: 0.30234	valid_1's l2: 249.388	valid_1's mse_score: 249.388
# [3400]	training's l2: 0.277246	training's mse_score: 0.277246	valid_1's l2: 249.314	valid_1's mse_score: 249.314
# [3500]	training's l2: 0.254583	training's mse_score: 0.254583	valid_1's l2: 249.239	valid_1's mse_score: 249.239
# [3600]	training's l2: 0.235097	training's mse_score: 0.235097	valid_1's l2: 249.187	valid_1's mse_score: 249.187
# [3700]	training's l2: 0.216753	training's mse_score: 0.216753	valid_1's l2: 249.159	valid_1's mse_score: 249.159
# [3800]	training's l2: 0.200941	training's mse_score: 0.200941	valid_1's l2: 249.105	valid_1's mse_score: 249.105
# [3900]	training's l2: 0.186351	training's mse_score: 0.186351	valid_1's l2: 249.064	valid_1's mse_score: 249.064
# [4000]	training's l2: 0.172757	training's mse_score: 0.172757	valid_1's l2: 249.027	valid_1's mse_score: 249.027
# [4100]	training's l2: 0.161352	training's mse_score: 0.161352	valid_1's l2: 248.997	valid_1's mse_score: 248.997
# [4200]	training's l2: 0.150571	training's mse_score: 0.150571	valid_1's l2: 248.963	valid_1's mse_score: 248.963
# [4300]	training's l2: 0.140599	training's mse_score: 0.140599	valid_1's l2: 248.921	valid_1's mse_score: 248.921
# [4400]	training's l2: 0.13183	training's mse_score: 0.13183	valid_1's l2: 248.867	valid_1's mse_score: 248.867
# [4500]	training's l2: 0.123913	training's mse_score: 0.123913	valid_1's l2: 248.839	valid_1's mse_score: 248.839
# [4600]	training's l2: 0.116541	training's mse_score: 0.116541	valid_1's l2: 248.812	valid_1's mse_score: 248.812
# [4700]	training's l2: 0.109934	training's mse_score: 0.109934	valid_1's l2: 248.797	valid_1's mse_score: 248.797
# [4800]	training's l2: 0.103917	training's mse_score: 0.103917	valid_1's l2: 248.772	valid_1's mse_score: 248.772
# [4900]	training's l2: 0.0986664	training's mse_score: 0.0986664	valid_1's l2: 248.74	valid_1's mse_score: 248.74
# [5000]	training's l2: 0.0934316	training's mse_score: 0.0934316	valid_1's l2: 248.716	valid_1's mse_score: 248.716
# [5100]	training's l2: 0.0884657	training's mse_score: 0.0884657	valid_1's l2: 248.709	valid_1's mse_score: 248.709
# Early stopping, best iteration is:
# [5054]	training's l2: 0.0906158	training's mse_score: 0.0906158	valid_1's l2: 248.704	valid_1's mse_score: 248.704
# fold  4
# /opt/conda/envs/python3/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_0', 'cat_1', 'cat_10', 'cat_11', 'cat_12', 'cat_13', 'cat_14', 'cat_15', 'cat_16', 'cat_17', 'cat_18', 'cat_19', 'cat_2', 'cat_3', 'cat_4', 'cat_5', 'cat_6', 'cat_7', 'cat_8', 'cat_9']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 347.97	training's mse_score: 347.97	valid_1's l2: 603.605	valid_1's mse_score: 603.605
# [200]	training's l2: 127.954	training's mse_score: 127.954	valid_1's l2: 395.362	valid_1's mse_score: 395.362
# [300]	training's l2: 69.5366	training's mse_score: 69.5366	valid_1's l2: 335.321	valid_1's mse_score: 335.321
# [400]	training's l2: 43.9892	training's mse_score: 43.9892	valid_1's l2: 307.97	valid_1's mse_score: 307.97
# [500]	training's l2: 29.7762	training's mse_score: 29.7762	valid_1's l2: 291.728	valid_1's mse_score: 291.728
# [600]	training's l2: 21.2434	training's mse_score: 21.2434	valid_1's l2: 280.945	valid_1's mse_score: 280.945
# [700]	training's l2: 15.7181	training's mse_score: 15.7181	valid_1's l2: 274.184	valid_1's mse_score: 274.184
# [800]	training's l2: 11.979	training's mse_score: 11.979	valid_1's l2: 269.374	valid_1's mse_score: 269.374
# [900]	training's l2: 9.28179	training's mse_score: 9.28179	valid_1's l2: 265.253	valid_1's mse_score: 265.253
# [1000]	training's l2: 7.31975	training's mse_score: 7.31975	valid_1's l2: 262.354	valid_1's mse_score: 262.354
# [1100]	training's l2: 5.873	training's mse_score: 5.873	valid_1's l2: 260.322	valid_1's mse_score: 260.322
# [1200]	training's l2: 4.79451	training's mse_score: 4.79451	valid_1's l2: 258.535	valid_1's mse_score: 258.535
# [1300]	training's l2: 3.91944	training's mse_score: 3.91944	valid_1's l2: 257.158	valid_1's mse_score: 257.158
# [1400]	training's l2: 3.24537	training's mse_score: 3.24537	valid_1's l2: 255.969	valid_1's mse_score: 255.969
# [1500]	training's l2: 2.74459	training's mse_score: 2.74459	valid_1's l2: 255.036	valid_1's mse_score: 255.036
# [1600]	training's l2: 2.32371	training's mse_score: 2.32371	valid_1's l2: 254.234	valid_1's mse_score: 254.234
# [1700]	training's l2: 1.99268	training's mse_score: 1.99268	valid_1's l2: 253.574	valid_1's mse_score: 253.574
# [1800]	training's l2: 1.72156	training's mse_score: 1.72156	valid_1's l2: 253.119	valid_1's mse_score: 253.119
# [1900]	training's l2: 1.48947	training's mse_score: 1.48947	valid_1's l2: 252.73	valid_1's mse_score: 252.73
# [2000]	training's l2: 1.29999	training's mse_score: 1.29999	valid_1's l2: 252.352	valid_1's mse_score: 252.352
# [2100]	training's l2: 1.13781	training's mse_score: 1.13781	valid_1's l2: 252.032	valid_1's mse_score: 252.032
# [2200]	training's l2: 0.994849	training's mse_score: 0.994849	valid_1's l2: 251.651	valid_1's mse_score: 251.651
# [2300]	training's l2: 0.877556	training's mse_score: 0.877556	valid_1's l2: 251.396	valid_1's mse_score: 251.396
# [2400]	training's l2: 0.780368	training's mse_score: 0.780368	valid_1's l2: 251.202	valid_1's mse_score: 251.202
# [2500]	training's l2: 0.694703	training's mse_score: 0.694703	valid_1's l2: 251.02	valid_1's mse_score: 251.02
# [2600]	training's l2: 0.62334	training's mse_score: 0.62334	valid_1's l2: 250.851	valid_1's mse_score: 250.851
# [2700]	training's l2: 0.559017	training's mse_score: 0.559017	valid_1's l2: 250.685	valid_1's mse_score: 250.685
# [2800]	training's l2: 0.504332	training's mse_score: 0.504332	valid_1's l2: 250.538	valid_1's mse_score: 250.538
# [2900]	training's l2: 0.45612	training's mse_score: 0.45612	valid_1's l2: 250.459	valid_1's mse_score: 250.459
# [3000]	training's l2: 0.41251	training's mse_score: 0.41251	valid_1's l2: 250.333	valid_1's mse_score: 250.333
# [3100]	training's l2: 0.376064	training's mse_score: 0.376064	valid_1's l2: 250.257	valid_1's mse_score: 250.257
# [3200]	training's l2: 0.342364	training's mse_score: 0.342364	valid_1's l2: 250.183	valid_1's mse_score: 250.183
# [3300]	training's l2: 0.313167	training's mse_score: 0.313167	valid_1's l2: 250.111	valid_1's mse_score: 250.111
# [3400]	training's l2: 0.288365	training's mse_score: 0.288365	valid_1's l2: 250.065	valid_1's mse_score: 250.065
# [3500]	training's l2: 0.265007	training's mse_score: 0.265007	valid_1's l2: 249.995	valid_1's mse_score: 249.995
# [3600]	training's l2: 0.243982	training's mse_score: 0.243982	valid_1's l2: 249.949	valid_1's mse_score: 249.949
# [3700]	training's l2: 0.226204	training's mse_score: 0.226204	valid_1's l2: 249.903	valid_1's mse_score: 249.903
# [3800]	training's l2: 0.209739	training's mse_score: 0.209739	valid_1's l2: 249.85	valid_1's mse_score: 249.85
# [3900]	training's l2: 0.194766	training's mse_score: 0.194766	valid_1's l2: 249.812	valid_1's mse_score: 249.812
# [4000]	training's l2: 0.18143	training's mse_score: 0.18143	valid_1's l2: 249.766	valid_1's mse_score: 249.766
# [4100]	training's l2: 0.16973	training's mse_score: 0.16973	valid_1's l2: 249.725	valid_1's mse_score: 249.725
# [4200]	training's l2: 0.157971	training's mse_score: 0.157971	valid_1's l2: 249.696	valid_1's mse_score: 249.696
# [4300]	training's l2: 0.147737	training's mse_score: 0.147737	valid_1's l2: 249.675	valid_1's mse_score: 249.675
# Early stopping, best iteration is:
# [4260]	training's l2: 0.151815	training's mse_score: 0.151815	valid_1's l2: 249.671	valid_1's mse_score: 249.671
# fold  5
# /opt/conda/envs/python3/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_0', 'cat_1', 'cat_10', 'cat_11', 'cat_12', 'cat_13', 'cat_14', 'cat_15', 'cat_16', 'cat_17', 'cat_18', 'cat_19', 'cat_2', 'cat_3', 'cat_4', 'cat_5', 'cat_6', 'cat_7', 'cat_8', 'cat_9']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 345.766	training's mse_score: 345.766	valid_1's l2: 632.017	valid_1's mse_score: 632.017
# [200]	training's l2: 127.554	training's mse_score: 127.554	valid_1's l2: 425.104	valid_1's mse_score: 425.104
# [300]	training's l2: 69.5681	training's mse_score: 69.5681	valid_1's l2: 369.946	valid_1's mse_score: 369.946
# [400]	training's l2: 43.3878	training's mse_score: 43.3878	valid_1's l2: 344.16	valid_1's mse_score: 344.16
# [500]	training's l2: 29.3949	training's mse_score: 29.3949	valid_1's l2: 328.469	valid_1's mse_score: 328.469
# [600]	training's l2: 20.8474	training's mse_score: 20.8474	valid_1's l2: 318.596	valid_1's mse_score: 318.596
# [700]	training's l2: 15.3277	training's mse_score: 15.3277	valid_1's l2: 311.386	valid_1's mse_score: 311.386
# [800]	training's l2: 11.6153	training's mse_score: 11.6153	valid_1's l2: 306.876	valid_1's mse_score: 306.876
# [900]	training's l2: 9.09031	training's mse_score: 9.09031	valid_1's l2: 303.318	valid_1's mse_score: 303.318
# [1000]	training's l2: 7.17313	training's mse_score: 7.17313	valid_1's l2: 300.907	valid_1's mse_score: 300.907
# [1100]	training's l2: 5.70779	training's mse_score: 5.70779	valid_1's l2: 298.957	valid_1's mse_score: 298.957
# [1200]	training's l2: 4.64662	training's mse_score: 4.64662	valid_1's l2: 296.996	valid_1's mse_score: 296.996
# [1300]	training's l2: 3.81474	training's mse_score: 3.81474	valid_1's l2: 295.806	valid_1's mse_score: 295.806
# [1400]	training's l2: 3.18473	training's mse_score: 3.18473	valid_1's l2: 294.796	valid_1's mse_score: 294.796
# [1500]	training's l2: 2.66959	training's mse_score: 2.66959	valid_1's l2: 294.043	valid_1's mse_score: 294.043
# [1600]	training's l2: 2.26866	training's mse_score: 2.26866	valid_1's l2: 293.214	valid_1's mse_score: 293.214
# [1700]	training's l2: 1.93822	training's mse_score: 1.93822	valid_1's l2: 292.65	valid_1's mse_score: 292.65
# [1800]	training's l2: 1.667	training's mse_score: 1.667	valid_1's l2: 292.247	valid_1's mse_score: 292.247
# [1900]	training's l2: 1.44496	training's mse_score: 1.44496	valid_1's l2: 291.882	valid_1's mse_score: 291.882
# [2000]	training's l2: 1.2604	training's mse_score: 1.2604	valid_1's l2: 291.454	valid_1's mse_score: 291.454
# [2100]	training's l2: 1.10372	training's mse_score: 1.10372	valid_1's l2: 291.163	valid_1's mse_score: 291.163
# [2200]	training's l2: 0.974347	training's mse_score: 0.974347	valid_1's l2: 290.996	valid_1's mse_score: 290.996
# [2300]	training's l2: 0.862888	training's mse_score: 0.862888	valid_1's l2: 290.745	valid_1's mse_score: 290.745
# [2400]	training's l2: 0.766628	training's mse_score: 0.766628	valid_1's l2: 290.535	valid_1's mse_score: 290.535
# [2500]	training's l2: 0.682072	training's mse_score: 0.682072	valid_1's l2: 290.386	valid_1's mse_score: 290.386
# [2600]	training's l2: 0.608416	training's mse_score: 0.608416	valid_1's l2: 290.239	valid_1's mse_score: 290.239
# [2700]	training's l2: 0.545446	training's mse_score: 0.545446	valid_1's l2: 290.139	valid_1's mse_score: 290.139
# [2800]	training's l2: 0.49315	training's mse_score: 0.49315	valid_1's l2: 290.027	valid_1's mse_score: 290.027
# [2900]	training's l2: 0.445607	training's mse_score: 0.445607	valid_1's l2: 289.94	valid_1's mse_score: 289.94
# [3000]	training's l2: 0.404943	training's mse_score: 0.404943	valid_1's l2: 289.881	valid_1's mse_score: 289.881
# [3100]	training's l2: 0.369296	training's mse_score: 0.369296	valid_1's l2: 289.78	valid_1's mse_score: 289.78
# [3200]	training's l2: 0.337312	training's mse_score: 0.337312	valid_1's l2: 289.736	valid_1's mse_score: 289.736
# [3300]	training's l2: 0.307787	training's mse_score: 0.307787	valid_1's l2: 289.663	valid_1's mse_score: 289.663
# [3400]	training's l2: 0.282812	training's mse_score: 0.282812	valid_1's l2: 289.595	valid_1's mse_score: 289.595
# [3500]	training's l2: 0.260254	training's mse_score: 0.260254	valid_1's l2: 289.543	valid_1's mse_score: 289.543
# Early stopping, best iteration is:
# [3515]	training's l2: 0.257107	training's mse_score: 0.257107	valid_1's l2: 289.54	valid_1's mse_score: 289.54
# fold  6
# /opt/conda/envs/python3/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_0', 'cat_1', 'cat_10', 'cat_11', 'cat_12', 'cat_13', 'cat_14', 'cat_15', 'cat_16', 'cat_17', 'cat_18', 'cat_19', 'cat_2', 'cat_3', 'cat_4', 'cat_5', 'cat_6', 'cat_7', 'cat_8', 'cat_9']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 339.875	training's mse_score: 339.875	valid_1's l2: 600.162	valid_1's mse_score: 600.162
# [200]	training's l2: 124.702	training's mse_score: 124.702	valid_1's l2: 386.998	valid_1's mse_score: 386.998
# [300]	training's l2: 69.0369	training's mse_score: 69.0369	valid_1's l2: 333.078	valid_1's mse_score: 333.078
# [400]	training's l2: 43.438	training's mse_score: 43.438	valid_1's l2: 306.387	valid_1's mse_score: 306.387
# [500]	training's l2: 29.2943	training's mse_score: 29.2943	valid_1's l2: 290.172	valid_1's mse_score: 290.172
# [600]	training's l2: 20.9821	training's mse_score: 20.9821	valid_1's l2: 279.564	valid_1's mse_score: 279.564
# [700]	training's l2: 15.4628	training's mse_score: 15.4628	valid_1's l2: 272.934	valid_1's mse_score: 272.934
# [800]	training's l2: 11.6717	training's mse_score: 11.6717	valid_1's l2: 268.21	valid_1's mse_score: 268.21
# [900]	training's l2: 9.00817	training's mse_score: 9.00817	valid_1's l2: 264.364	valid_1's mse_score: 264.364
# [1000]	training's l2: 7.102	training's mse_score: 7.102	valid_1's l2: 262.053	valid_1's mse_score: 262.053
# [1100]	training's l2: 5.714	training's mse_score: 5.714	valid_1's l2: 259.863	valid_1's mse_score: 259.863
# [1200]	training's l2: 4.63797	training's mse_score: 4.63797	valid_1's l2: 258.225	valid_1's mse_score: 258.225
# [1300]	training's l2: 3.82246	training's mse_score: 3.82246	valid_1's l2: 256.85	valid_1's mse_score: 256.85
# [1400]	training's l2: 3.20358	training's mse_score: 3.20358	valid_1's l2: 255.756	valid_1's mse_score: 255.756
# [1500]	training's l2: 2.69334	training's mse_score: 2.69334	valid_1's l2: 254.902	valid_1's mse_score: 254.902
# [1600]	training's l2: 2.28947	training's mse_score: 2.28947	valid_1's l2: 254.067	valid_1's mse_score: 254.067
# [1700]	training's l2: 1.9555	training's mse_score: 1.9555	valid_1's l2: 253.44	valid_1's mse_score: 253.44
# [1800]	training's l2: 1.68188	training's mse_score: 1.68188	valid_1's l2: 252.994	valid_1's mse_score: 252.994
# [1900]	training's l2: 1.46047	training's mse_score: 1.46047	valid_1's l2: 252.588	valid_1's mse_score: 252.588
# [2000]	training's l2: 1.26179	training's mse_score: 1.26179	valid_1's l2: 252.187	valid_1's mse_score: 252.187
# [2100]	training's l2: 1.10224	training's mse_score: 1.10224	valid_1's l2: 251.882	valid_1's mse_score: 251.882
# [2200]	training's l2: 0.97395	training's mse_score: 0.97395	valid_1's l2: 251.705	valid_1's mse_score: 251.705
# [2300]	training's l2: 0.860841	training's mse_score: 0.860841	valid_1's l2: 251.49	valid_1's mse_score: 251.49
# [2400]	training's l2: 0.767161	training's mse_score: 0.767161	valid_1's l2: 251.313	valid_1's mse_score: 251.313
# [2500]	training's l2: 0.685579	training's mse_score: 0.685579	valid_1's l2: 251.166	valid_1's mse_score: 251.166
# [2600]	training's l2: 0.614041	training's mse_score: 0.614041	valid_1's l2: 251.023	valid_1's mse_score: 251.023
# [2700]	training's l2: 0.553161	training's mse_score: 0.553161	valid_1's l2: 250.873	valid_1's mse_score: 250.873
# [2800]	training's l2: 0.49717	training's mse_score: 0.49717	valid_1's l2: 250.791	valid_1's mse_score: 250.791
# [2900]	training's l2: 0.44989	training's mse_score: 0.44989	valid_1's l2: 250.703	valid_1's mse_score: 250.703
# [3000]	training's l2: 0.406749	training's mse_score: 0.406749	valid_1's l2: 250.621	valid_1's mse_score: 250.621
# [3100]	training's l2: 0.369819	training's mse_score: 0.369819	valid_1's l2: 250.54	valid_1's mse_score: 250.54
# [3200]	training's l2: 0.33746	training's mse_score: 0.33746	valid_1's l2: 250.455	valid_1's mse_score: 250.455
# [3300]	training's l2: 0.308168	training's mse_score: 0.308168	valid_1's l2: 250.363	valid_1's mse_score: 250.363
# [3400]	training's l2: 0.282306	training's mse_score: 0.282306	valid_1's l2: 250.272	valid_1's mse_score: 250.272
# [3500]	training's l2: 0.259188	training's mse_score: 0.259188	valid_1's l2: 250.217	valid_1's mse_score: 250.217
# [3600]	training's l2: 0.238515	training's mse_score: 0.238515	valid_1's l2: 250.167	valid_1's mse_score: 250.167
# [3700]	training's l2: 0.220059	training's mse_score: 0.220059	valid_1's l2: 250.101	valid_1's mse_score: 250.101
# [3800]	training's l2: 0.204042	training's mse_score: 0.204042	valid_1's l2: 250.076	valid_1's mse_score: 250.076
# [3900]	training's l2: 0.189462	training's mse_score: 0.189462	valid_1's l2: 250.042	valid_1's mse_score: 250.042
# [4000]	training's l2: 0.176085	training's mse_score: 0.176085	valid_1's l2: 250.014	valid_1's mse_score: 250.014
# [4100]	training's l2: 0.16412	training's mse_score: 0.16412	valid_1's l2: 249.982	valid_1's mse_score: 249.982
# [4200]	training's l2: 0.152821	training's mse_score: 0.152821	valid_1's l2: 249.958	valid_1's mse_score: 249.958
# [4300]	training's l2: 0.143395	training's mse_score: 0.143395	valid_1's l2: 249.929	valid_1's mse_score: 249.929
# [4400]	training's l2: 0.134666	training's mse_score: 0.134666	valid_1's l2: 249.898	valid_1's mse_score: 249.898
# [4500]	training's l2: 0.126413	training's mse_score: 0.126413	valid_1's l2: 249.89	valid_1's mse_score: 249.89
# Early stopping, best iteration is:
# [4467]	training's l2: 0.128932	training's mse_score: 0.128932	valid_1's l2: 249.887	valid_1's mse_score: 249.887
# fold  7
# /opt/conda/envs/python3/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_0', 'cat_1', 'cat_10', 'cat_11', 'cat_12', 'cat_13', 'cat_14', 'cat_15', 'cat_16', 'cat_17', 'cat_18', 'cat_19', 'cat_2', 'cat_3', 'cat_4', 'cat_5', 'cat_6', 'cat_7', 'cat_8', 'cat_9']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 345.651	training's mse_score: 345.651	valid_1's l2: 596.414	valid_1's mse_score: 596.414
# [200]	training's l2: 126.825	training's mse_score: 126.825	valid_1's l2: 375.579	valid_1's mse_score: 375.579
# [300]	training's l2: 69.8285	training's mse_score: 69.8285	valid_1's l2: 319.238	valid_1's mse_score: 319.238
# [400]	training's l2: 43.8131	training's mse_score: 43.8131	valid_1's l2: 293.802	valid_1's mse_score: 293.802
# [500]	training's l2: 29.3089	training's mse_score: 29.3089	valid_1's l2: 278.558	valid_1's mse_score: 278.558
# [600]	training's l2: 20.7557	training's mse_score: 20.7557	valid_1's l2: 269.28	valid_1's mse_score: 269.28
# [700]	training's l2: 15.1973	training's mse_score: 15.1973	valid_1's l2: 263.051	valid_1's mse_score: 263.051
# [800]	training's l2: 11.4974	training's mse_score: 11.4974	valid_1's l2: 258.476	valid_1's mse_score: 258.476
# [900]	training's l2: 8.95596	training's mse_score: 8.95596	valid_1's l2: 255.223	valid_1's mse_score: 255.223
# [1000]	training's l2: 7.0577	training's mse_score: 7.0577	valid_1's l2: 252.599	valid_1's mse_score: 252.599
# [1100]	training's l2: 5.64946	training's mse_score: 5.64946	valid_1's l2: 250.896	valid_1's mse_score: 250.896
# [1200]	training's l2: 4.60684	training's mse_score: 4.60684	valid_1's l2: 249.153	valid_1's mse_score: 249.153
# [1300]	training's l2: 3.81697	training's mse_score: 3.81697	valid_1's l2: 248.134	valid_1's mse_score: 248.134
# [1400]	training's l2: 3.17645	training's mse_score: 3.17645	valid_1's l2: 247.042	valid_1's mse_score: 247.042
# [1500]	training's l2: 2.68936	training's mse_score: 2.68936	valid_1's l2: 246.374	valid_1's mse_score: 246.374
# [1600]	training's l2: 2.2788	training's mse_score: 2.2788	valid_1's l2: 245.708	valid_1's mse_score: 245.708
# [1700]	training's l2: 1.95905	training's mse_score: 1.95905	valid_1's l2: 245.268	valid_1's mse_score: 245.268
# [1800]	training's l2: 1.69806	training's mse_score: 1.69806	valid_1's l2: 244.805	valid_1's mse_score: 244.805
# [1900]	training's l2: 1.46824	training's mse_score: 1.46824	valid_1's l2: 244.47	valid_1's mse_score: 244.47
# [2000]	training's l2: 1.28934	training's mse_score: 1.28934	valid_1's l2: 244.05	valid_1's mse_score: 244.05
# [2100]	training's l2: 1.13527	training's mse_score: 1.13527	valid_1's l2: 243.836	valid_1's mse_score: 243.836
# [2200]	training's l2: 1.00816	training's mse_score: 1.00816	valid_1's l2: 243.615	valid_1's mse_score: 243.615
# [2300]	training's l2: 0.896874	training's mse_score: 0.896874	valid_1's l2: 243.415	valid_1's mse_score: 243.415
# [2400]	training's l2: 0.804513	training's mse_score: 0.804513	valid_1's l2: 243.248	valid_1's mse_score: 243.248
# [2500]	training's l2: 0.724683	training's mse_score: 0.724683	valid_1's l2: 243.1	valid_1's mse_score: 243.1
# [2600]	training's l2: 0.655722	training's mse_score: 0.655722	valid_1's l2: 242.955	valid_1's mse_score: 242.955
# [2700]	training's l2: 0.595643	training's mse_score: 0.595643	valid_1's l2: 242.854	valid_1's mse_score: 242.854
# [2800]	training's l2: 0.542593	training's mse_score: 0.542593	valid_1's l2: 242.744	valid_1's mse_score: 242.744
# [2900]	training's l2: 0.495183	training's mse_score: 0.495183	valid_1's l2: 242.644	valid_1's mse_score: 242.644
# [3000]	training's l2: 0.455374	training's mse_score: 0.455374	valid_1's l2: 242.573	valid_1's mse_score: 242.573
# [3100]	training's l2: 0.419559	training's mse_score: 0.419559	valid_1's l2: 242.512	valid_1's mse_score: 242.512
# [3200]	training's l2: 0.388982	training's mse_score: 0.388982	valid_1's l2: 242.45	valid_1's mse_score: 242.45
# [3300]	training's l2: 0.359337	training's mse_score: 0.359337	valid_1's l2: 242.386	valid_1's mse_score: 242.386
# [3400]	training's l2: 0.335429	training's mse_score: 0.335429	valid_1's l2: 242.328	valid_1's mse_score: 242.328
# [3500]	training's l2: 0.313731	training's mse_score: 0.313731	valid_1's l2: 242.261	valid_1's mse_score: 242.261
# [3600]	training's l2: 0.294063	training's mse_score: 0.294063	valid_1's l2: 242.221	valid_1's mse_score: 242.221
# [3700]	training's l2: 0.275949	training's mse_score: 0.275949	valid_1's l2: 242.194	valid_1's mse_score: 242.194
# [3800]	training's l2: 0.259993	training's mse_score: 0.259993	valid_1's l2: 242.162	valid_1's mse_score: 242.162
# [3900]	training's l2: 0.244809	training's mse_score: 0.244809	valid_1's l2: 242.123	valid_1's mse_score: 242.123
# [4000]	training's l2: 0.231979	training's mse_score: 0.231979	valid_1's l2: 242.099	valid_1's mse_score: 242.099
# [4100]	training's l2: 0.219816	training's mse_score: 0.219816	valid_1's l2: 242.066	valid_1's mse_score: 242.066
# [4200]	training's l2: 0.209188	training's mse_score: 0.209188	valid_1's l2: 242.043	valid_1's mse_score: 242.043
# Early stopping, best iteration is:
# [4193]	training's l2: 0.209822	training's mse_score: 0.209822	valid_1's l2: 242.04	valid_1's mse_score: 242.04
# fold  8
# /opt/conda/envs/python3/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_0', 'cat_1', 'cat_10', 'cat_11', 'cat_12', 'cat_13', 'cat_14', 'cat_15', 'cat_16', 'cat_17', 'cat_18', 'cat_19', 'cat_2', 'cat_3', 'cat_4', 'cat_5', 'cat_6', 'cat_7', 'cat_8', 'cat_9']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 337.92	training's mse_score: 337.92	valid_1's l2: 655.822	valid_1's mse_score: 655.822
# [200]	training's l2: 125.207	training's mse_score: 125.207	valid_1's l2: 426.246	valid_1's mse_score: 426.246
# [300]	training's l2: 69.002	training's mse_score: 69.002	valid_1's l2: 364.581	valid_1's mse_score: 364.581
# [400]	training's l2: 43.3076	training's mse_score: 43.3076	valid_1's l2: 334.532	valid_1's mse_score: 334.532
# [500]	training's l2: 29.1311	training's mse_score: 29.1311	valid_1's l2: 316.593	valid_1's mse_score: 316.593
# [600]	training's l2: 20.5512	training's mse_score: 20.5512	valid_1's l2: 305.203	valid_1's mse_score: 305.203
# [700]	training's l2: 15.2334	training's mse_score: 15.2334	valid_1's l2: 297.73	valid_1's mse_score: 297.73
# [800]	training's l2: 11.5289	training's mse_score: 11.5289	valid_1's l2: 292.156	valid_1's mse_score: 292.156
# [900]	training's l2: 8.91058	training's mse_score: 8.91058	valid_1's l2: 287.8	valid_1's mse_score: 287.8
# [1000]	training's l2: 7.03699	training's mse_score: 7.03699	valid_1's l2: 284.993	valid_1's mse_score: 284.993
# [1100]	training's l2: 5.65099	training's mse_score: 5.65099	valid_1's l2: 282.773	valid_1's mse_score: 282.773
# [1200]	training's l2: 4.60699	training's mse_score: 4.60699	valid_1's l2: 281.023	valid_1's mse_score: 281.023
# [1300]	training's l2: 3.79898	training's mse_score: 3.79898	valid_1's l2: 279.73	valid_1's mse_score: 279.73
# [1400]	training's l2: 3.16642	training's mse_score: 3.16642	valid_1's l2: 278.582	valid_1's mse_score: 278.582
# [1500]	training's l2: 2.66526	training's mse_score: 2.66526	valid_1's l2: 277.689	valid_1's mse_score: 277.689
# [1600]	training's l2: 2.25742	training's mse_score: 2.25742	valid_1's l2: 276.932	valid_1's mse_score: 276.932
# [1700]	training's l2: 1.92504	training's mse_score: 1.92504	valid_1's l2: 276.269	valid_1's mse_score: 276.269
# [1800]	training's l2: 1.65381	training's mse_score: 1.65381	valid_1's l2: 275.693	valid_1's mse_score: 275.693
# [1900]	training's l2: 1.4303	training's mse_score: 1.4303	valid_1's l2: 275.135	valid_1's mse_score: 275.135
# [2000]	training's l2: 1.24649	training's mse_score: 1.24649	valid_1's l2: 274.829	valid_1's mse_score: 274.829
# [2100]	training's l2: 1.08671	training's mse_score: 1.08671	valid_1's l2: 274.444	valid_1's mse_score: 274.444
# [2200]	training's l2: 0.959999	training's mse_score: 0.959999	valid_1's l2: 274.226	valid_1's mse_score: 274.226
# [2300]	training's l2: 0.847341	training's mse_score: 0.847341	valid_1's l2: 274.029	valid_1's mse_score: 274.029
# [2400]	training's l2: 0.754858	training's mse_score: 0.754858	valid_1's l2: 273.815	valid_1's mse_score: 273.815
# [2500]	training's l2: 0.675853	training's mse_score: 0.675853	valid_1's l2: 273.675	valid_1's mse_score: 273.675
# [2600]	training's l2: 0.6071	training's mse_score: 0.6071	valid_1's l2: 273.484	valid_1's mse_score: 273.484
# [2700]	training's l2: 0.544526	training's mse_score: 0.544526	valid_1's l2: 273.377	valid_1's mse_score: 273.377
# [2800]	training's l2: 0.490385	training's mse_score: 0.490385	valid_1's l2: 273.25	valid_1's mse_score: 273.25
# [2900]	training's l2: 0.444251	training's mse_score: 0.444251	valid_1's l2: 273.12	valid_1's mse_score: 273.12
# [3000]	training's l2: 0.40435	training's mse_score: 0.40435	valid_1's l2: 273.021	valid_1's mse_score: 273.021
# [3100]	training's l2: 0.369108	training's mse_score: 0.369108	valid_1's l2: 272.962	valid_1's mse_score: 272.962
# [3200]	training's l2: 0.336568	training's mse_score: 0.336568	valid_1's l2: 272.876	valid_1's mse_score: 272.876
# [3300]	training's l2: 0.30951	training's mse_score: 0.30951	valid_1's l2: 272.792	valid_1's mse_score: 272.792
# [3400]	training's l2: 0.284817	training's mse_score: 0.284817	valid_1's l2: 272.736	valid_1's mse_score: 272.736
# [3500]	training's l2: 0.262237	training's mse_score: 0.262237	valid_1's l2: 272.711	valid_1's mse_score: 272.711
# [3600]	training's l2: 0.242581	training's mse_score: 0.242581	valid_1's l2: 272.627	valid_1's mse_score: 272.627
# [3700]	training's l2: 0.224892	training's mse_score: 0.224892	valid_1's l2: 272.566	valid_1's mse_score: 272.566
# [3800]	training's l2: 0.208712	training's mse_score: 0.208712	valid_1's l2: 272.518	valid_1's mse_score: 272.518
# [3900]	training's l2: 0.194644	training's mse_score: 0.194644	valid_1's l2: 272.476	valid_1's mse_score: 272.476
# [4000]	training's l2: 0.181781	training's mse_score: 0.181781	valid_1's l2: 272.449	valid_1's mse_score: 272.449
# [4100]	training's l2: 0.170318	training's mse_score: 0.170318	valid_1's l2: 272.441	valid_1's mse_score: 272.441
# [4200]	training's l2: 0.15955	training's mse_score: 0.15955	valid_1's l2: 272.396	valid_1's mse_score: 272.396
# [4300]	training's l2: 0.149898	training's mse_score: 0.149898	valid_1's l2: 272.367	valid_1's mse_score: 272.367
# [4400]	training's l2: 0.141094	training's mse_score: 0.141094	valid_1's l2: 272.346	valid_1's mse_score: 272.346
# [4500]	training's l2: 0.132949	training's mse_score: 0.132949	valid_1's l2: 272.314	valid_1's mse_score: 272.314
# [4600]	training's l2: 0.125197	training's mse_score: 0.125197	valid_1's l2: 272.291	valid_1's mse_score: 272.291
# [4700]	training's l2: 0.118534	training's mse_score: 0.118534	valid_1's l2: 272.277	valid_1's mse_score: 272.277
# [4800]	training's l2: 0.112382	training's mse_score: 0.112382	valid_1's l2: 272.258	valid_1's mse_score: 272.258
# [4900]	training's l2: 0.106857	training's mse_score: 0.106857	valid_1's l2: 272.245	valid_1's mse_score: 272.245
# [5000]	training's l2: 0.10165	training's mse_score: 0.10165	valid_1's l2: 272.221	valid_1's mse_score: 272.221
# [5100]	training's l2: 0.0968557	training's mse_score: 0.0968557	valid_1's l2: 272.205	valid_1's mse_score: 272.205
# Early stopping, best iteration is:
# [5099]	training's l2: 0.0968888	training's mse_score: 0.0968888	valid_1's l2: 272.204	valid_1's mse_score: 272.204
# fold  9
# /opt/conda/envs/python3/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_0', 'cat_1', 'cat_10', 'cat_11', 'cat_12', 'cat_13', 'cat_14', 'cat_15', 'cat_16', 'cat_17', 'cat_18', 'cat_19', 'cat_2', 'cat_3', 'cat_4', 'cat_5', 'cat_6', 'cat_7', 'cat_8', 'cat_9']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 347.167	training's mse_score: 347.167	valid_1's l2: 531.646	valid_1's mse_score: 531.646
# [200]	training's l2: 128.309	training's mse_score: 128.309	valid_1's l2: 332.822	valid_1's mse_score: 332.822
# [300]	training's l2: 70.6322	training's mse_score: 70.6322	valid_1's l2: 280.774	valid_1's mse_score: 280.774
# [400]	training's l2: 44.4209	training's mse_score: 44.4209	valid_1's l2: 254.197	valid_1's mse_score: 254.197
# [500]	training's l2: 30.0037	training's mse_score: 30.0037	valid_1's l2: 239.548	valid_1's mse_score: 239.548
# [600]	training's l2: 21.001	training's mse_score: 21.001	valid_1's l2: 229.626	valid_1's mse_score: 229.626
# [700]	training's l2: 15.4838	training's mse_score: 15.4838	valid_1's l2: 223.477	valid_1's mse_score: 223.477
# [800]	training's l2: 11.7586	training's mse_score: 11.7586	valid_1's l2: 218.792	valid_1's mse_score: 218.792
# [900]	training's l2: 9.15069	training's mse_score: 9.15069	valid_1's l2: 215.605	valid_1's mse_score: 215.605
# [1000]	training's l2: 7.24054	training's mse_score: 7.24054	valid_1's l2: 212.832	valid_1's mse_score: 212.832
# [1100]	training's l2: 5.8228	training's mse_score: 5.8228	valid_1's l2: 211.01	valid_1's mse_score: 211.01
# [1200]	training's l2: 4.7358	training's mse_score: 4.7358	valid_1's l2: 209.338	valid_1's mse_score: 209.338
# [1300]	training's l2: 3.91063	training's mse_score: 3.91063	valid_1's l2: 208.189	valid_1's mse_score: 208.189
# [1400]	training's l2: 3.27222	training's mse_score: 3.27222	valid_1's l2: 207.23	valid_1's mse_score: 207.23
# [1500]	training's l2: 2.74844	training's mse_score: 2.74844	valid_1's l2: 206.466	valid_1's mse_score: 206.466
# [1600]	training's l2: 2.33148	training's mse_score: 2.33148	valid_1's l2: 205.914	valid_1's mse_score: 205.914
# [1700]	training's l2: 1.99086	training's mse_score: 1.99086	valid_1's l2: 205.264	valid_1's mse_score: 205.264
# [1800]	training's l2: 1.71461	training's mse_score: 1.71461	valid_1's l2: 204.806	valid_1's mse_score: 204.806
# [1900]	training's l2: 1.49124	training's mse_score: 1.49124	valid_1's l2: 204.398	valid_1's mse_score: 204.398
# [2000]	training's l2: 1.29622	training's mse_score: 1.29622	valid_1's l2: 204.13	valid_1's mse_score: 204.13
# [2100]	training's l2: 1.13521	training's mse_score: 1.13521	valid_1's l2: 203.847	valid_1's mse_score: 203.847
# [2200]	training's l2: 0.999957	training's mse_score: 0.999957	valid_1's l2: 203.566	valid_1's mse_score: 203.566
# [2300]	training's l2: 0.88378	training's mse_score: 0.88378	valid_1's l2: 203.401	valid_1's mse_score: 203.401
# [2400]	training's l2: 0.786205	training's mse_score: 0.786205	valid_1's l2: 203.215	valid_1's mse_score: 203.215
# [2500]	training's l2: 0.699616	training's mse_score: 0.699616	valid_1's l2: 203.075	valid_1's mse_score: 203.075
# [2600]	training's l2: 0.626684	training's mse_score: 0.626684	valid_1's l2: 202.939	valid_1's mse_score: 202.939
# [2700]	training's l2: 0.562789	training's mse_score: 0.562789	valid_1's l2: 202.81	valid_1's mse_score: 202.81
# [2800]	training's l2: 0.5069	training's mse_score: 0.5069	valid_1's l2: 202.674	valid_1's mse_score: 202.674
# [2900]	training's l2: 0.459247	training's mse_score: 0.459247	valid_1's l2: 202.572	valid_1's mse_score: 202.572
# [3000]	training's l2: 0.418602	training's mse_score: 0.418602	valid_1's l2: 202.497	valid_1's mse_score: 202.497
# [3100]	training's l2: 0.38135	training's mse_score: 0.38135	valid_1's l2: 202.396	valid_1's mse_score: 202.396
# [3200]	training's l2: 0.348685	training's mse_score: 0.348685	valid_1's l2: 202.339	valid_1's mse_score: 202.339
# [3300]	training's l2: 0.319431	training's mse_score: 0.319431	valid_1's l2: 202.279	valid_1's mse_score: 202.279
# [3400]	training's l2: 0.293725	training's mse_score: 0.293725	valid_1's l2: 202.182	valid_1's mse_score: 202.182
# [3500]	training's l2: 0.270799	training's mse_score: 0.270799	valid_1's l2: 202.163	valid_1's mse_score: 202.163
# [3600]	training's l2: 0.249358	training's mse_score: 0.249358	valid_1's l2: 202.081	valid_1's mse_score: 202.081
# [3700]	training's l2: 0.229731	training's mse_score: 0.229731	valid_1's l2: 202.03	valid_1's mse_score: 202.03
# [3800]	training's l2: 0.21324	training's mse_score: 0.21324	valid_1's l2: 201.99	valid_1's mse_score: 201.99
# [3900]	training's l2: 0.198214	training's mse_score: 0.198214	valid_1's l2: 201.948	valid_1's mse_score: 201.948
# [4000]	training's l2: 0.184744	training's mse_score: 0.184744	valid_1's l2: 201.908	valid_1's mse_score: 201.908
# [4100]	training's l2: 0.17216	training's mse_score: 0.17216	valid_1's l2: 201.887	valid_1's mse_score: 201.887
# [4200]	training's l2: 0.160829	training's mse_score: 0.160829	valid_1's l2: 201.858	valid_1's mse_score: 201.858
# [4300]	training's l2: 0.150287	training's mse_score: 0.150287	valid_1's l2: 201.826	valid_1's mse_score: 201.826
# [4400]	training's l2: 0.141178	training's mse_score: 0.141178	valid_1's l2: 201.811	valid_1's mse_score: 201.811
# [4500]	training's l2: 0.132886	training's mse_score: 0.132886	valid_1's l2: 201.785	valid_1's mse_score: 201.785
# [4600]	training's l2: 0.125207	training's mse_score: 0.125207	valid_1's l2: 201.761	valid_1's mse_score: 201.761
# [4700]	training's l2: 0.118222	training's mse_score: 0.118222	valid_1's l2: 201.753	valid_1's mse_score: 201.753
# Early stopping, best iteration is:
# [4670]	training's l2: 0.120364	training's mse_score: 0.120364	valid_1's l2: 201.748	valid_1's mse_score: 201.748
# fold  10
# /opt/conda/envs/python3/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_0', 'cat_1', 'cat_10', 'cat_11', 'cat_12', 'cat_13', 'cat_14', 'cat_15', 'cat_16', 'cat_17', 'cat_18', 'cat_19', 'cat_2', 'cat_3', 'cat_4', 'cat_5', 'cat_6', 'cat_7', 'cat_8', 'cat_9']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 340.511	training's mse_score: 340.511	valid_1's l2: 746.031	valid_1's mse_score: 746.031
# [200]	training's l2: 127.125	training's mse_score: 127.125	valid_1's l2: 510.166	valid_1's mse_score: 510.166
# [300]	training's l2: 69.5334	training's mse_score: 69.5334	valid_1's l2: 444.792	valid_1's mse_score: 444.792
# [400]	training's l2: 43.5897	training's mse_score: 43.5897	valid_1's l2: 413.319	valid_1's mse_score: 413.319
# [500]	training's l2: 29.349	training's mse_score: 29.349	valid_1's l2: 395.485	valid_1's mse_score: 395.485
# [600]	training's l2: 20.6591	training's mse_score: 20.6591	valid_1's l2: 383.79	valid_1's mse_score: 383.79
# [700]	training's l2: 15.1698	training's mse_score: 15.1698	valid_1's l2: 375.985	valid_1's mse_score: 375.985
# [800]	training's l2: 11.4515	training's mse_score: 11.4515	valid_1's l2: 370.687	valid_1's mse_score: 370.687
# [900]	training's l2: 8.91971	training's mse_score: 8.91971	valid_1's l2: 367.03	valid_1's mse_score: 367.03
# [1000]	training's l2: 7.06454	training's mse_score: 7.06454	valid_1's l2: 364.244	valid_1's mse_score: 364.244
# [1100]	training's l2: 5.6843	training's mse_score: 5.6843	valid_1's l2: 362.114	valid_1's mse_score: 362.114
# [1200]	training's l2: 4.60165	training's mse_score: 4.60165	valid_1's l2: 360.287	valid_1's mse_score: 360.287
# [1300]	training's l2: 3.78376	training's mse_score: 3.78376	valid_1's l2: 358.912	valid_1's mse_score: 358.912
# [1400]	training's l2: 3.17079	training's mse_score: 3.17079	valid_1's l2: 357.806	valid_1's mse_score: 357.806
# [1500]	training's l2: 2.66612	training's mse_score: 2.66612	valid_1's l2: 356.986	valid_1's mse_score: 356.986
# [1600]	training's l2: 2.25861	training's mse_score: 2.25861	valid_1's l2: 356.221	valid_1's mse_score: 356.221
# [1700]	training's l2: 1.93063	training's mse_score: 1.93063	valid_1's l2: 355.723	valid_1's mse_score: 355.723
# [1800]	training's l2: 1.67405	training's mse_score: 1.67405	valid_1's l2: 355.138	valid_1's mse_score: 355.138
# [1900]	training's l2: 1.44025	training's mse_score: 1.44025	valid_1's l2: 354.677	valid_1's mse_score: 354.677
# [2000]	training's l2: 1.24976	training's mse_score: 1.24976	valid_1's l2: 354.252	valid_1's mse_score: 354.252
# [2100]	training's l2: 1.10183	training's mse_score: 1.10183	valid_1's l2: 353.946	valid_1's mse_score: 353.946
# [2200]	training's l2: 0.970081	training's mse_score: 0.970081	valid_1's l2: 353.662	valid_1's mse_score: 353.662
# [2300]	training's l2: 0.855573	training's mse_score: 0.855573	valid_1's l2: 353.377	valid_1's mse_score: 353.377
# [2400]	training's l2: 0.761339	training's mse_score: 0.761339	valid_1's l2: 353.176	valid_1's mse_score: 353.176
# [2500]	training's l2: 0.678562	training's mse_score: 0.678562	valid_1's l2: 352.988	valid_1's mse_score: 352.988
# [2600]	training's l2: 0.606814	training's mse_score: 0.606814	valid_1's l2: 352.871	valid_1's mse_score: 352.871
# [2700]	training's l2: 0.545687	training's mse_score: 0.545687	valid_1's l2: 352.718	valid_1's mse_score: 352.718
# [2800]	training's l2: 0.491182	training's mse_score: 0.491182	valid_1's l2: 352.579	valid_1's mse_score: 352.579
# [2900]	training's l2: 0.444339	training's mse_score: 0.444339	valid_1's l2: 352.465	valid_1's mse_score: 352.465
# [3000]	training's l2: 0.403661	training's mse_score: 0.403661	valid_1's l2: 352.352	valid_1's mse_score: 352.352
# [3100]	training's l2: 0.367124	training's mse_score: 0.367124	valid_1's l2: 352.198	valid_1's mse_score: 352.198
# [3200]	training's l2: 0.333789	training's mse_score: 0.333789	valid_1's l2: 352.119	valid_1's mse_score: 352.119
# [3300]	training's l2: 0.305381	training's mse_score: 0.305381	valid_1's l2: 352.069	valid_1's mse_score: 352.069
# [3400]	training's l2: 0.280599	training's mse_score: 0.280599	valid_1's l2: 351.997	valid_1's mse_score: 351.997
# [3500]	training's l2: 0.258172	training's mse_score: 0.258172	valid_1's l2: 351.932	valid_1's mse_score: 351.932
# [3600]	training's l2: 0.237987	training's mse_score: 0.237987	valid_1's l2: 351.872	valid_1's mse_score: 351.872
# [3700]	training's l2: 0.219716	training's mse_score: 0.219716	valid_1's l2: 351.818	valid_1's mse_score: 351.818
# [3800]	training's l2: 0.203585	training's mse_score: 0.203585	valid_1's l2: 351.773	valid_1's mse_score: 351.773
# [3900]	training's l2: 0.189161	training's mse_score: 0.189161	valid_1's l2: 351.742	valid_1's mse_score: 351.742
# [4000]	training's l2: 0.176302	training's mse_score: 0.176302	valid_1's l2: 351.718	valid_1's mse_score: 351.718
# [4100]	training's l2: 0.164214	training's mse_score: 0.164214	valid_1's l2: 351.681	valid_1's mse_score: 351.681
# [4200]	training's l2: 0.153306	training's mse_score: 0.153306	valid_1's l2: 351.628	valid_1's mse_score: 351.628
# [4300]	training's l2: 0.143673	training's mse_score: 0.143673	valid_1's l2: 351.624	valid_1's mse_score: 351.624
# [4400]	training's l2: 0.134522	training's mse_score: 0.134522	valid_1's l2: 351.606	valid_1's mse_score: 351.606
# [4500]	training's l2: 0.126335	training's mse_score: 0.126335	valid_1's l2: 351.572	valid_1's mse_score: 351.572
# [4600]	training's l2: 0.118749	training's mse_score: 0.118749	valid_1's l2: 351.566	valid_1's mse_score: 351.566
# [4700]	training's l2: 0.111774	training's mse_score: 0.111774	valid_1's l2: 351.546	valid_1's mse_score: 351.546
# [4800]	training's l2: 0.105567	training's mse_score: 0.105567	valid_1's l2: 351.527	valid_1's mse_score: 351.527
# [4900]	training's l2: 0.0998019	training's mse_score: 0.0998019	valid_1's l2: 351.502	valid_1's mse_score: 351.502
# [5000]	training's l2: 0.0946757	training's mse_score: 0.0946757	valid_1's l2: 351.476	valid_1's mse_score: 351.476
# [5100]	training's l2: 0.0899788	training's mse_score: 0.0899788	valid_1's l2: 351.458	valid_1's mse_score: 351.458
# [5200]	training's l2: 0.0854942	training's mse_score: 0.0854942	valid_1's l2: 351.447	valid_1's mse_score: 351.447
# Early stopping, best iteration is:
# [5196]	training's l2: 0.0856782	training's mse_score: 0.0856782	valid_1's l2: 351.446	valid_1's mse_score: 351.446
# train mse:  272.8472780040184

# %%
imp['gain'] = imp[[f for f in imp.columns if 'gain' in f]].sum(axis=1)/10
imp['split'] = imp[[f for f in imp.columns if 'split' in f]].sum(axis=1)/10

imp = imp[['feat', 'gain', 'split']]
imp
# Out:
#         feat          gain    split
# 0      num_0  7.003265e+06    820.4
# 1      num_1  4.160235e+07   1196.6
# 2      num_3  1.261791e+07    964.4
# 3      num_4  9.811510e+06    176.0
# 4      num_5  2.397947e+06    664.8
# 5      num_6  5.525129e+06   1222.4
# 6      num_7  3.762070e+05    170.4
# 7      num_8  1.251110e+05     39.6
# 8      num_9  7.263034e+04      9.6
# 9     num_11  5.326924e+06   2567.2
# 10    num_12  3.253194e+06   2350.2
# 11    num_13  1.260458e+04     19.8
# 12    num_14  4.677349e+06   1000.7
# 13    num_15  4.330240e+07   1726.7
# 14    num_17  1.218760e+07   1326.4
# 15    num_18  1.157312e+07    286.4
# 16    num_19  5.735888e+04     23.1
# 17    num_20  5.634722e+06   1529.7
# 18    num_21  1.024986e+04      2.5
# 19    num_22  3.698522e+06    571.8
# 20    num_23  2.262748e+05    117.8
# 21    num_24  1.713583e+06   1055.1
# 22    num_25  5.259990e+06   1662.5
# 23    num_26  5.208652e+06   1478.4
# 24    num_27  3.383413e+06   2660.9
# 25    num_28  3.088960e+07    663.3
# 26    num_29  2.823131e+07    911.7
# 27    num_30  2.838414e+07    576.3
# 28    num_31  1.389000e+07    500.1
# 29    num_32  8.787679e+07    349.1
# 30    num_33  8.297365e+06    721.4
# 31    num_34  9.098977e+06    652.5
# 32    num_35  1.081917e+02      1.3
# 33    num_36  1.032504e+06    158.5
# 34    num_38  4.565585e+06   1207.9
# 35    num_39  2.910446e+06   1918.2
# 36    num_40  1.741718e+06   1772.6
# 37    num_41  2.161958e+07   1291.4
# 38    num_42  2.224241e+07    741.8
# 39    num_43  4.629467e+07   1003.9
# 40    num_44  6.263289e+07   1003.0
# 41    num_45  1.108311e+07    978.7
# 42    num_46  7.029079e+06    670.0
# 43    num_47  2.013151e+07    970.0
# 44    num_48  1.879635e+07    855.4
# 45    num_49  3.984434e+03      0.6
# 46    num_50  1.434592e+05    108.2
# 47    num_52  5.324232e+06   1325.2
# 48    num_53  5.159211e+06   2123.6
# 49    num_54  2.805042e+06   2392.8
# 50    num_55  2.490647e+07   1476.2
# 51    num_56  7.062120e+06   1667.7
# 52    num_57  1.176567e+07   1105.5
# 53    num_58  1.124165e+06    331.3
# 54    num_59  9.490405e+06   2105.5
# 55    num_60  6.997021e+06    664.5
# 56    num_61  2.701879e+06    685.3
# 57    num_62  9.936620e+06    888.0
# 58    num_63  5.325954e+06    551.8
# 59    num_64  3.423051e+06   1026.9
# 60    num_65  8.909004e+06   1229.2
# 61    num_66  1.977287e+06   1128.1
# 62    num_67  5.759315e+06   2195.9
# 63    num_68  4.238697e+06   2589.1
# 64    num_69  5.439694e+06    633.0
# 65    num_70  1.112319e+07   1479.7
# 66    num_71  4.480546e+06   1529.5
# 67    num_72  3.340906e+06   1685.0
# 68    num_73  6.967813e+06   1752.1
# 69    num_74  2.742762e+06   1484.5
# 70    num_75  2.307835e+06    558.9
# 71    num_76  1.201733e+07   1279.8
# 72    num_77  1.104274e+05     19.8
# 73    num_78  5.520432e+06    946.8
# 74    num_79  6.067901e+06    917.8
# 75    num_80  5.320203e+06   1749.2
# 76    num_81  5.433132e+06   1974.2
# 77    num_82  7.404056e+06   2703.1
# 78    num_83  1.483568e+07   2147.3
# 79    num_84  1.256175e+07    603.1
# 80    num_85  4.619828e+07    533.5
# 81    num_86  5.018671e+06    906.6
# 82    num_87  1.396329e+06    457.5
# 83    num_88  4.540175e+06    290.1
# 84    num_89  1.048082e+07    329.3
# 85    num_90  8.883021e+06    785.9
# 86    num_91  0.000000e+00      0.0
# 87    num_92  2.279537e+05     67.3
# 88    num_94  1.031267e+07   1172.1
# 89    num_95  2.894361e+06   1411.8
# 90    num_96  1.893033e+06   1464.7
# 91    num_97  5.602383e+06   1472.0
# 92    num_98  3.758616e+06    356.9
# 93    num_99  2.136857e+06     44.5
# 94   num_100  3.454015e+06    662.4
# 95   num_101  6.895204e+05    228.4
# 96   num_102  8.274993e+06     76.0
# 97   num_103  1.618972e+06    334.2
# 98   num_104  1.215821e+06    516.6
# 99   num_105  0.000000e+00      0.0
# 100  num_106  0.000000e+00      0.0
# 101  num_109  4.036487e+06   1217.3
# 102  num_110  4.132780e+06   1478.6
# 103  num_111  6.267580e+05     99.3
# 104  num_112  2.881624e+06    642.7
# 105  num_113  1.924596e+06    762.1
# 106  num_114  8.897648e+06   1675.7
# 107  num_115  2.630937e+06    593.2
# 108  num_116  1.721212e+06    597.1
# 109  num_117  4.746931e+06    318.6
# 110  num_118  4.994268e+06   1280.0
# 111  num_119  2.485025e+04     31.3
# 112  num_120  1.514275e+04     19.2
# 113  num_121  8.979972e+06   1783.4
# 114  num_122  2.281208e+06    809.6
# 115  num_123  3.613279e+06   1331.1
# 116  num_124  1.901528e+06   1146.7
# 117  num_126  2.140920e+07    737.8
# 118  num_127  7.125999e+07    723.8
# 119  num_128  1.292548e+09   1136.0
# 120  num_129  7.806059e+06    498.7
# 121  num_130  4.904465e+07    327.2
# 122  num_131  2.316335e+06    417.9
# 123  num_132  3.934512e+07    717.9
# 124  num_133  0.000000e+00      0.0
# 125  num_134  3.590403e+04      9.0
# 126  num_136  1.785880e+06    163.4
# 127  num_137  3.023479e+06   1730.7
# 128  num_138  1.270442e+06   1650.3
# 129  num_139  1.514029e+07    872.2
# 130  num_140  1.316028e+06    258.0
# 131  num_141  3.365504e+05     48.2
# 132  num_142  1.347173e+07    408.7
# 133  num_143  2.138674e+06    215.7
# 134  num_144  6.365580e+05     75.1
# 135  num_145  1.416610e+06    301.8
# 136  num_146  2.030580e+06    221.5
# 137  num_147  0.000000e+00      0.0
# 138  num_148  0.000000e+00      0.0
# 139  num_151  3.981062e+06   1021.9
# 140  num_152  6.350277e+06   1410.1
# 141  num_153  2.146868e+06     65.3
# 142  num_154  9.646348e+06    748.3
# 143  num_155  8.278190e+06   1660.7
# 144  num_156  3.210947e+06   1113.9
# 145  num_157  3.134155e+06    727.4
# 146  num_158  1.509688e+06    832.3
# 147  num_159  6.045794e+06    398.0
# 148  num_160  6.955119e+06   1405.4
# 149  num_161  4.814682e+04      3.2
# 150  num_162  2.098205e+03      6.8
# 151  num_163  1.108750e+06    263.2
# 152  num_164  6.113206e+05    256.2
# 153  num_165  3.709083e+06   1281.0
# 154  num_166  1.697527e+06   1206.3
# 155  num_168  9.412830e+06    483.2
# 156  num_169  4.996439e+07    454.8
# 157  num_170  4.566709e+06    568.2
# 158  num_171  1.977376e+06    414.9
# 159  num_172  6.002588e+06    279.5
# 160  num_173  8.676221e+05    137.9
# 161  num_174  7.438185e+06    544.7
# 162  num_175  0.000000e+00      0.0
# 163  num_176  5.548578e+02      1.4
# 164  num_178  1.080202e+05     24.7
# 165  num_179  2.956912e+06   1212.8
# 166  num_180  1.727635e+06   1337.6
# 167  num_181  4.059067e+06    765.9
# 168  num_182  9.244172e+05    195.8
# 169  num_183  3.580104e+05     20.5
# 170  num_184  1.794359e+06    364.8
# 171  num_185  5.580238e+05    139.4
# 172  num_186  2.549061e+06     51.3
# 173  num_187  1.105207e+06    177.8
# 174  num_188  8.571087e+05    291.6
# 175  num_189  0.000000e+00      0.0
# 176  num_190  0.000000e+00      0.0
# 177  num_193  3.490501e+06    987.0
# 178  num_194  3.342246e+06   1298.2
# 179  num_195  4.227933e+05     54.6
# 180  num_196  3.585870e+06    516.0
# 181  num_197  1.407501e+06    721.3
# 182  num_198  9.940820e+06   1703.1
# 183  num_199  3.311031e+06    564.5
# 184  num_200  1.407162e+06    633.4
# 185  num_201  5.975046e+06    299.5
# 186  num_202  3.297763e+06   1013.8
# 187  num_203  3.030009e+01      0.4
# 188  num_204  5.913166e+01      2.8
# 189  num_205  6.433725e+04     42.5
# 190  num_206  1.211909e+05     73.1
# 191  num_207  4.366249e+06   1307.9
# 192  num_208  2.281299e+06   1101.7
# 193  num_210  2.490340e+07    719.7
# 194  num_211  2.353027e+07    621.1
# 195  num_212  2.543955e+10   1132.8
# 196  num_213  2.442051e+06    545.6
# 197  num_214  1.000583e+07    392.5
# 198  num_215  1.648553e+06    240.1
# 199  num_216  1.804223e+07    690.3
# 200  num_217  0.000000e+00      0.0
# 201  num_218  6.221593e+00      0.3
# 202  num_220  5.967120e+02      2.0
# 203  num_221  3.127271e+06   1692.1
# 204  num_222  1.751409e+06   1752.7
# 205  num_223  9.273915e+06    794.5
# 206  num_224  1.144861e+06    184.2
# 207  num_225  3.554445e+05     32.1
# 208  num_226  8.007594e+06    382.9
# 209  num_227  2.437967e+06    171.8
# 210  num_228  5.352264e+05     64.5
# 211  num_229  8.200129e+05    206.0
# 212  num_230  1.077094e+06    161.7
# 213  num_231  0.000000e+00      0.0
# 214  num_232  0.000000e+00      0.0
# 215  num_235  6.768977e+06    925.3
# 216  num_236  3.192241e+06   1378.0
# 217  num_237  8.909603e+05     65.9
# 218  num_238  7.554474e+06    774.7
# 219  num_239  7.347653e+06   2120.3
# 220  num_240  3.914967e+06   1174.3
# 221  num_241  2.917655e+06    771.7
# 222  num_242  1.473497e+06    974.7
# 223  num_243  6.590836e+06    410.2
# 224  num_244  5.010581e+06   1713.9
# 225  num_245  0.000000e+00      0.0
# 226  num_246  6.133517e+02      3.0
# 227  num_247  8.666993e+02      5.4
# 228  num_248  8.482871e+05    113.5
# 229  num_249  2.832009e+06   1564.6
# 230  num_250  1.612542e+06   1311.4
# 231  num_252  6.367060e+06   1515.4
# 232  num_253  7.983311e+06   2633.8
# 233  num_254  8.134322e+06   2042.9
# 234  num_255  8.061272e+06   2374.3
# 235  num_256  6.240340e+06   2288.4
# 236  num_257  5.099976e+06   1087.8
# 237  num_258  6.700958e+06   1301.1
# 238  num_259  0.000000e+00      0.0
# 239  num_260  6.776941e+03      6.8
# 240  num_261  1.155332e+05      2.7
# 241  num_262  1.454276e+06    636.0
# 242  num_263  5.655463e+06   3242.4
# 243  num_264  7.820309e+06   3307.7
# 244  num_265  0.000000e+00      0.0
# 245  num_266  2.078124e+06    878.3
# 246  num_267  2.168812e+06   1442.1
# 247  num_268  5.809466e+06   1397.5
# 248  num_269  2.544008e+06   1190.8
# 249  num_270  5.378839e+05    520.6
# 250  num_271  1.906434e+06    762.4
# 251  num_272  1.999055e+06    915.3
# 252  num_273  0.000000e+00      0.0
# 253  num_274  0.000000e+00      0.0
# 254  num_277  2.664031e+06   3644.2
# 255  num_278  2.198726e+06   3475.1
# 256  num_279  5.853814e+05    200.8
# 257  num_280  4.091722e+06    845.9
# 258  num_281  9.214854e+06   1652.0
# 259  num_282  5.249184e+06   1041.6
# 260  num_283  2.332505e+06    752.5
# 261  num_284  1.922383e+06   1004.9
# 262  num_285  1.032113e+07    565.5
# 263  num_286  5.534896e+06   1286.6
# 264  num_287  7.993959e+04     31.0
# 265  num_288  1.113231e+06    221.6
# 266  num_289  7.959461e+06   1969.1
# 267  num_290  5.905636e+06   1329.1
# 268  num_291  4.536893e+06   1239.8
# 269  num_292  1.753785e+06   1364.9
# 270  num_293  2.256734e+06   1930.9
# 271  num_294  8.423631e+06    932.4
# 272  num_295  1.064380e+07   1791.4
# 273  num_296  8.588695e+06   1501.1
# 274  num_297  3.705328e+06    989.7
# 275  num_298  3.955813e+06   1209.9
# 276  num_299  8.789852e+06    867.2
# 277  num_300  8.454769e+06   1692.4
# 278  num_301  1.356794e+04     29.7
# 279  num_302  8.484666e+05    198.8
# 280  num_303  1.156944e+07   2225.6
# 281  num_304  6.942066e+06   1377.2
# 282  num_305  3.898326e+06   1813.3
# 283  num_306  3.286737e+06   1812.6
# 284  num_308  3.034864e+06   2513.3
# 285  num_309  3.945974e+06   1136.5
# 286  num_310  3.191181e+06   1090.2
# 287  num_311  7.029146e+06   2074.9
# 288  num_312  3.891502e+06   1260.3
# 289  num_313  4.265288e+06   2227.6
# 290  num_314  8.860735e+02     54.1
# 291  num_315  3.523014e+06   1065.1
# 292  num_316  4.005635e+06   1280.5
# 293  num_317  4.623294e+06   2452.2
# 294  num_318  2.692504e+06   1071.2
# 295  num_319  4.075838e+06   4985.9
# 296  num_320  5.835380e+06   2528.0
# 297  num_321  7.015292e+01      5.8
# 298  num_322  2.441855e+06   2637.8
# 299  num_323  4.404444e+06   2080.7
# 300  num_324  3.669370e+06   1879.0
# 301  num_325  8.174659e+06   1892.5
# 302  num_326  4.627378e+06   1605.6
# 303  num_327  2.855719e+06   3425.0
# 304  num_328  1.016645e+05   1075.2
# 305  num_329  9.673200e+05    380.7
# 306  num_330  6.267434e+06   1386.2
# 307  num_331  1.316468e+07   2915.4
# 308  num_332  4.703247e+06   1305.3
# 309  num_333  5.564337e+06   4897.6
# 310  num_334  1.278353e+07   2233.3
# 311  num_335  1.401619e+05   1069.3
# 312  num_336  0.000000e+00      0.0
# 313  num_337  5.464669e+06   1238.3
# 314  num_338  2.950696e+06    413.0
# 315  num_339  5.047058e+07   2391.0
# 316  num_340  2.927675e+06    530.9
# 317  num_341  2.940980e+06    738.0
# 318  num_342  3.446547e+06    731.2
# 319  num_343  3.208222e+06    940.9
# 320  num_344  5.425291e+06    995.0
# 321  num_345  7.847002e+06   1148.5
# 322  num_346  4.365129e+04      5.5
# 323  num_347  4.495589e+04      8.1
# 324  num_348  2.473421e+07    400.3
# 325  num_349  5.144475e+07    405.6
# 326  num_350  5.305940e+04      7.1
# 327  num_351  2.005190e+05     10.7
# 328  num_352  2.151259e+09    669.6
# 329  num_353  5.001448e+09    647.6
# 330  num_354  2.783027e+06    863.2
# 331  num_355  2.909264e+05     37.3
# 332  num_356  2.475199e+06    578.8
# 333  num_357  2.356708e+05     40.4
# 334  num_358  2.427516e+07    695.3
# 335  num_359  3.869797e+06    156.7
# 336  num_360  1.379528e+08    709.6
# 337  num_361  3.834046e+06    175.6
# 338    cat_0  1.765971e+07   1279.8
# 339    cat_1  5.515756e+08  49841.1
# 340    cat_2  5.088799e+06    196.4
# 341    cat_3  7.347478e+06    395.6
# 342    cat_4  5.596932e+06    497.9
# 343    cat_5  9.839232e+08   2939.7
# 344    cat_6  1.363523e+09   4315.6
# 345    cat_7  8.565134e+08   8352.6
# 346    cat_8  8.887953e+06   5999.8
# 347    cat_9  1.168422e+07  14208.3
# 348   cat_10  1.860013e+07  26451.4
# 349   cat_11  1.505897e+08  26706.0
# 350   cat_12  5.306878e+07  25053.9
# 351   cat_13  2.445149e+07  30144.4
# 352   cat_14  5.006044e+06    182.1
# 353   cat_15  1.830357e+07   1860.7
# 354   cat_16  6.684831e+07  33223.6
# 355   cat_17  2.526815e+06     88.1
# 356   cat_18  2.430569e+07   1987.8
# 357   cat_19  5.698877e+07  46487.4

# %%
imp = imp.sort_values(by=['gain'], ascending=False)
imp = imp.reset_index(drop=True)
imp.to_pickle("imp.pkl")

# %%
imp
# Out:
#         feat          gain    split
# 0    num_212  2.543955e+10   1132.8
# 1    num_353  5.001448e+09    647.6
# 2    num_352  2.151259e+09    669.6
# 3      cat_6  1.363523e+09   4315.6
# 4    num_128  1.292548e+09   1136.0
# 5      cat_5  9.839232e+08   2939.7
# 6      cat_7  8.565134e+08   8352.6
# 7      cat_1  5.515756e+08  49841.1
# 8     cat_11  1.505897e+08  26706.0
# 9    num_360  1.379528e+08    709.6
# 10    num_32  8.787679e+07    349.1
# 11   num_127  7.125999e+07    723.8
# 12    cat_16  6.684831e+07  33223.6
# 13    num_44  6.263289e+07   1003.0
# 14    cat_19  5.698877e+07  46487.4
# 15    cat_12  5.306878e+07  25053.9
# 16   num_349  5.144475e+07    405.6
# 17   num_339  5.047058e+07   2391.0
# 18   num_169  4.996439e+07    454.8
# 19   num_130  4.904465e+07    327.2
# 20    num_43  4.629467e+07   1003.9
# 21    num_85  4.619828e+07    533.5
# 22    num_15  4.330240e+07   1726.7
# 23     num_1  4.160235e+07   1196.6
# 24   num_132  3.934512e+07    717.9
# 25    num_28  3.088960e+07    663.3
# 26    num_30  2.838414e+07    576.3
# 27    num_29  2.823131e+07    911.7
# 28    num_55  2.490647e+07   1476.2
# 29   num_210  2.490340e+07    719.7
# 30   num_348  2.473421e+07    400.3
# 31    cat_13  2.445149e+07  30144.4
# 32    cat_18  2.430569e+07   1987.8
# 33   num_358  2.427516e+07    695.3
# 34   num_211  2.353027e+07    621.1
# 35    num_42  2.224241e+07    741.8
# 36    num_41  2.161958e+07   1291.4
# 37   num_126  2.140920e+07    737.8
# 38    num_47  2.013151e+07    970.0
# 39    num_48  1.879635e+07    855.4
# 40    cat_10  1.860013e+07  26451.4
# 41    cat_15  1.830357e+07   1860.7
# 42   num_216  1.804223e+07    690.3
# 43     cat_0  1.765971e+07   1279.8
# 44   num_139  1.514029e+07    872.2
# 45    num_83  1.483568e+07   2147.3
# 46    num_31  1.389000e+07    500.1
# 47   num_142  1.347173e+07    408.7
# 48   num_331  1.316468e+07   2915.4
# 49   num_334  1.278353e+07   2233.3
# 50     num_3  1.261791e+07    964.4
# 51    num_84  1.256175e+07    603.1
# 52    num_17  1.218760e+07   1326.4
# 53    num_76  1.201733e+07   1279.8
# 54    num_57  1.176567e+07   1105.5
# 55     cat_9  1.168422e+07  14208.3
# 56    num_18  1.157312e+07    286.4
# 57   num_303  1.156944e+07   2225.6
# 58    num_70  1.112319e+07   1479.7
# 59    num_45  1.108311e+07    978.7
# 60   num_295  1.064380e+07   1791.4
# 61    num_89  1.048082e+07    329.3
# 62   num_285  1.032113e+07    565.5
# 63    num_94  1.031267e+07   1172.1
# 64   num_214  1.000583e+07    392.5
# 65   num_198  9.940820e+06   1703.1
# 66    num_62  9.936620e+06    888.0
# 67     num_4  9.811510e+06    176.0
# 68   num_154  9.646348e+06    748.3
# 69    num_59  9.490405e+06   2105.5
# 70   num_168  9.412830e+06    483.2
# 71   num_223  9.273915e+06    794.5
# 72   num_281  9.214854e+06   1652.0
# 73    num_34  9.098977e+06    652.5
# 74   num_121  8.979972e+06   1783.4
# 75    num_65  8.909004e+06   1229.2
# 76   num_114  8.897648e+06   1675.7
# 77     cat_8  8.887953e+06   5999.8
# 78    num_90  8.883021e+06    785.9
# 79   num_299  8.789852e+06    867.2
# 80   num_296  8.588695e+06   1501.1
# 81   num_300  8.454769e+06   1692.4
# 82   num_294  8.423631e+06    932.4
# 83    num_33  8.297365e+06    721.4
# 84   num_155  8.278190e+06   1660.7
# 85   num_102  8.274993e+06     76.0
# 86   num_325  8.174659e+06   1892.5
# 87   num_254  8.134322e+06   2042.9
# 88   num_255  8.061272e+06   2374.3
# 89   num_226  8.007594e+06    382.9
# 90   num_253  7.983311e+06   2633.8
# 91   num_289  7.959461e+06   1969.1
# 92   num_345  7.847002e+06   1148.5
# 93   num_264  7.820309e+06   3307.7
# 94   num_129  7.806059e+06    498.7
# 95   num_238  7.554474e+06    774.7
# 96   num_174  7.438185e+06    544.7
# 97    num_82  7.404056e+06   2703.1
# 98   num_239  7.347653e+06   2120.3
# 99     cat_3  7.347478e+06    395.6
# 100   num_56  7.062120e+06   1667.7
# 101  num_311  7.029146e+06   2074.9
# 102   num_46  7.029079e+06    670.0
# 103    num_0  7.003265e+06    820.4
# 104   num_60  6.997021e+06    664.5
# 105   num_73  6.967813e+06   1752.1
# 106  num_160  6.955119e+06   1405.4
# 107  num_304  6.942066e+06   1377.2
# 108  num_235  6.768977e+06    925.3
# 109  num_258  6.700958e+06   1301.1
# 110  num_243  6.590836e+06    410.2
# 111  num_252  6.367060e+06   1515.4
# 112  num_152  6.350277e+06   1410.1
# 113  num_330  6.267434e+06   1386.2
# 114  num_256  6.240340e+06   2288.4
# 115   num_79  6.067901e+06    917.8
# 116  num_159  6.045794e+06    398.0
# 117  num_172  6.002588e+06    279.5
# 118  num_201  5.975046e+06    299.5
# 119  num_290  5.905636e+06   1329.1
# 120  num_320  5.835380e+06   2528.0
# 121  num_268  5.809466e+06   1397.5
# 122   num_67  5.759315e+06   2195.9
# 123  num_263  5.655463e+06   3242.4
# 124   num_20  5.634722e+06   1529.7
# 125   num_97  5.602383e+06   1472.0
# 126    cat_4  5.596932e+06    497.9
# 127  num_333  5.564337e+06   4897.6
# 128  num_286  5.534896e+06   1286.6
# 129    num_6  5.525129e+06   1222.4
# 130   num_78  5.520432e+06    946.8
# 131  num_337  5.464669e+06   1238.3
# 132   num_69  5.439694e+06    633.0
# 133   num_81  5.433132e+06   1974.2
# 134  num_344  5.425291e+06    995.0
# 135   num_11  5.326924e+06   2567.2
# 136   num_63  5.325954e+06    551.8
# 137   num_52  5.324232e+06   1325.2
# 138   num_80  5.320203e+06   1749.2
# 139   num_25  5.259990e+06   1662.5
# 140  num_282  5.249184e+06   1041.6
# 141   num_26  5.208652e+06   1478.4
# 142   num_53  5.159211e+06   2123.6
# 143  num_257  5.099976e+06   1087.8
# 144    cat_2  5.088799e+06    196.4
# 145   num_86  5.018671e+06    906.6
# 146  num_244  5.010581e+06   1713.9
# 147   cat_14  5.006044e+06    182.1
# 148  num_118  4.994268e+06   1280.0
# 149  num_117  4.746931e+06    318.6
# 150  num_332  4.703247e+06   1305.3
# 151   num_14  4.677349e+06   1000.7
# 152  num_326  4.627378e+06   1605.6
# 153  num_317  4.623294e+06   2452.2
# 154  num_170  4.566709e+06    568.2
# 155   num_38  4.565585e+06   1207.9
# 156   num_88  4.540175e+06    290.1
# 157  num_291  4.536893e+06   1239.8
# 158   num_71  4.480546e+06   1529.5
# 159  num_323  4.404444e+06   2080.7
# 160  num_207  4.366249e+06   1307.9
# 161  num_313  4.265288e+06   2227.6
# 162   num_68  4.238697e+06   2589.1
# 163  num_110  4.132780e+06   1478.6
# 164  num_280  4.091722e+06    845.9
# 165  num_319  4.075838e+06   4985.9
# 166  num_181  4.059067e+06    765.9
# 167  num_109  4.036487e+06   1217.3
# 168  num_316  4.005635e+06   1280.5
# 169  num_151  3.981062e+06   1021.9
# 170  num_298  3.955813e+06   1209.9
# 171  num_309  3.945974e+06   1136.5
# 172  num_240  3.914967e+06   1174.3
# 173  num_305  3.898326e+06   1813.3
# 174  num_312  3.891502e+06   1260.3
# 175  num_359  3.869797e+06    156.7
# 176  num_361  3.834046e+06    175.6
# 177   num_98  3.758616e+06    356.9
# 178  num_165  3.709083e+06   1281.0
# 179  num_297  3.705328e+06    989.7
# 180   num_22  3.698522e+06    571.8
# 181  num_324  3.669370e+06   1879.0
# 182  num_123  3.613279e+06   1331.1
# 183  num_196  3.585870e+06    516.0
# 184  num_315  3.523014e+06   1065.1
# 185  num_193  3.490501e+06    987.0
# 186  num_100  3.454015e+06    662.4
# 187  num_342  3.446547e+06    731.2
# 188   num_64  3.423051e+06   1026.9
# 189   num_27  3.383413e+06   2660.9
# 190  num_194  3.342246e+06   1298.2
# 191   num_72  3.340906e+06   1685.0
# 192  num_199  3.311031e+06    564.5
# 193  num_202  3.297763e+06   1013.8
# 194  num_306  3.286737e+06   1812.6
# 195   num_12  3.253194e+06   2350.2
# 196  num_156  3.210947e+06   1113.9
# 197  num_343  3.208222e+06    940.9
# 198  num_236  3.192241e+06   1378.0
# 199  num_310  3.191181e+06   1090.2
# 200  num_157  3.134155e+06    727.4
# 201  num_221  3.127271e+06   1692.1
# 202  num_308  3.034864e+06   2513.3
# 203  num_137  3.023479e+06   1730.7
# 204  num_179  2.956912e+06   1212.8
# 205  num_338  2.950696e+06    413.0
# 206  num_341  2.940980e+06    738.0
# 207  num_340  2.927675e+06    530.9
# 208  num_241  2.917655e+06    771.7
# 209   num_39  2.910446e+06   1918.2
# 210   num_95  2.894361e+06   1411.8
# 211  num_112  2.881624e+06    642.7
# 212  num_327  2.855719e+06   3425.0
# 213  num_249  2.832009e+06   1564.6
# 214   num_54  2.805042e+06   2392.8
# 215  num_354  2.783027e+06    863.2
# 216   num_74  2.742762e+06   1484.5
# 217   num_61  2.701879e+06    685.3
# 218  num_318  2.692504e+06   1071.2
# 219  num_277  2.664031e+06   3644.2
# 220  num_115  2.630937e+06    593.2
# 221  num_186  2.549061e+06     51.3
# 222  num_269  2.544008e+06   1190.8
# 223   cat_17  2.526815e+06     88.1
# 224  num_356  2.475199e+06    578.8
# 225  num_213  2.442051e+06    545.6
# 226  num_322  2.441855e+06   2637.8
# 227  num_227  2.437967e+06    171.8
# 228    num_5  2.397947e+06    664.8
# 229  num_283  2.332505e+06    752.5
# 230  num_131  2.316335e+06    417.9
# 231   num_75  2.307835e+06    558.9
# 232  num_208  2.281299e+06   1101.7
# 233  num_122  2.281208e+06    809.6
# 234  num_293  2.256734e+06   1930.9
# 235  num_278  2.198726e+06   3475.1
# 236  num_267  2.168812e+06   1442.1
# 237  num_153  2.146868e+06     65.3
# 238  num_143  2.138674e+06    215.7
# 239   num_99  2.136857e+06     44.5
# 240  num_266  2.078124e+06    878.3
# 241  num_146  2.030580e+06    221.5
# 242  num_272  1.999055e+06    915.3
# 243  num_171  1.977376e+06    414.9
# 244   num_66  1.977287e+06   1128.1
# 245  num_113  1.924596e+06    762.1
# 246  num_284  1.922383e+06   1004.9
# 247  num_271  1.906434e+06    762.4
# 248  num_124  1.901528e+06   1146.7
# 249   num_96  1.893033e+06   1464.7
# 250  num_184  1.794359e+06    364.8
# 251  num_136  1.785880e+06    163.4
# 252  num_292  1.753785e+06   1364.9
# 253  num_222  1.751409e+06   1752.7
# 254   num_40  1.741718e+06   1772.6
# 255  num_180  1.727635e+06   1337.6
# 256  num_116  1.721212e+06    597.1
# 257   num_24  1.713583e+06   1055.1
# 258  num_166  1.697527e+06   1206.3
# 259  num_215  1.648553e+06    240.1
# 260  num_103  1.618972e+06    334.2
# 261  num_250  1.612542e+06   1311.4
# 262  num_158  1.509688e+06    832.3
# 263  num_242  1.473497e+06    974.7
# 264  num_262  1.454276e+06    636.0
# 265  num_145  1.416610e+06    301.8
# 266  num_197  1.407501e+06    721.3
# 267  num_200  1.407162e+06    633.4
# 268   num_87  1.396329e+06    457.5
# 269  num_140  1.316028e+06    258.0
# 270  num_138  1.270442e+06   1650.3
# 271  num_104  1.215821e+06    516.6
# 272  num_224  1.144861e+06    184.2
# 273   num_58  1.124165e+06    331.3
# 274  num_288  1.113231e+06    221.6
# 275  num_163  1.108750e+06    263.2
# 276  num_187  1.105207e+06    177.8
# 277  num_230  1.077094e+06    161.7
# 278   num_36  1.032504e+06    158.5
# 279  num_329  9.673200e+05    380.7
# 280  num_182  9.244172e+05    195.8
# 281  num_237  8.909603e+05     65.9
# 282  num_173  8.676221e+05    137.9
# 283  num_188  8.571087e+05    291.6
# 284  num_302  8.484666e+05    198.8
# 285  num_248  8.482871e+05    113.5
# 286  num_229  8.200129e+05    206.0
# 287  num_101  6.895204e+05    228.4
# 288  num_144  6.365580e+05     75.1
# 289  num_111  6.267580e+05     99.3
# 290  num_164  6.113206e+05    256.2
# 291  num_279  5.853814e+05    200.8
# 292  num_185  5.580238e+05    139.4
# 293  num_270  5.378839e+05    520.6
# 294  num_228  5.352264e+05     64.5
# 295  num_195  4.227933e+05     54.6
# 296    num_7  3.762070e+05    170.4
# 297  num_183  3.580104e+05     20.5
# 298  num_225  3.554445e+05     32.1
# 299  num_141  3.365504e+05     48.2
# 300  num_355  2.909264e+05     37.3
# 301  num_357  2.356708e+05     40.4
# 302   num_92  2.279537e+05     67.3
# 303   num_23  2.262748e+05    117.8
# 304  num_351  2.005190e+05     10.7
# 305   num_50  1.434592e+05    108.2
# 306  num_335  1.401619e+05   1069.3
# 307    num_8  1.251110e+05     39.6
# 308  num_206  1.211909e+05     73.1
# 309  num_261  1.155332e+05      2.7
# 310   num_77  1.104274e+05     19.8
# 311  num_178  1.080202e+05     24.7
# 312  num_328  1.016645e+05   1075.2
# 313  num_287  7.993959e+04     31.0
# 314    num_9  7.263034e+04      9.6
# 315  num_205  6.433725e+04     42.5
# 316   num_19  5.735888e+04     23.1
# 317  num_350  5.305940e+04      7.1
# 318  num_161  4.814682e+04      3.2
# 319  num_347  4.495589e+04      8.1
# 320  num_346  4.365129e+04      5.5
# 321  num_134  3.590403e+04      9.0
# 322  num_119  2.485025e+04     31.3
# 323  num_120  1.514275e+04     19.2
# 324  num_301  1.356794e+04     29.7
# 325   num_13  1.260458e+04     19.8
# 326   num_21  1.024986e+04      2.5
# 327  num_260  6.776941e+03      6.8
# 328   num_49  3.984434e+03      0.6
# 329  num_162  2.098205e+03      6.8
# 330  num_314  8.860735e+02     54.1
# 331  num_247  8.666993e+02      5.4
# 332  num_246  6.133517e+02      3.0
# 333  num_220  5.967120e+02      2.0
# 334  num_176  5.548578e+02      1.4
# 335   num_35  1.081917e+02      1.3
# 336  num_321  7.015292e+01      5.8
# 337  num_204  5.913166e+01      2.8
# 338  num_203  3.030009e+01      0.4
# 339  num_218  6.221593e+00      0.3
# 340  num_274  0.000000e+00      0.0
# 341  num_232  0.000000e+00      0.0
# 342  num_190  0.000000e+00      0.0
# 343   num_91  0.000000e+00      0.0
# 344  num_175  0.000000e+00      0.0
# 345  num_245  0.000000e+00      0.0
# 346  num_147  0.000000e+00      0.0
# 347  num_273  0.000000e+00      0.0
# 348  num_265  0.000000e+00      0.0
# 349  num_106  0.000000e+00      0.0
# 350  num_105  0.000000e+00      0.0
# 351  num_231  0.000000e+00      0.0
# 352  num_217  0.000000e+00      0.0
# 353  num_259  0.000000e+00      0.0
# 354  num_189  0.000000e+00      0.0
# 355  num_133  0.000000e+00      0.0
# 356  num_148  0.000000e+00      0.0
# 357  num_336  0.000000e+00      0.0

# %%
# train mse:  1174.767318829244
# train mse:  273.7163487202298

sub_FORMAT = "%Y/%m%d  %H:%M:%S"
UTC_FORMAT = "%Y-%m-%dT%H:%M:%S.%fZ"

def get_time(x, y):
    x = x.split(' ')[-1]
    x = datetime.datetime.strptime(x, UTC_FORMAT)
    day = y // 24 
    seconds = int((y - (y//24)*24)*3600)
    res = x + datetime.timedelta(days=day, seconds=seconds)
    str_res = res.strftime(sub_FORMAT)
    return res 

# result = pd.DataFrame({
#         'loadingOrder': test_loadingOrder, 
#         'label': test_pred,
#     })

result['timestamp'] = test_df['timestamp']
result['ETA'] = list(map(lambda x, y: get_time(x, y), result['timestamp'], result['label']))

# %%
test_data = pd.read_csv("data/B_testData0626.csv") 
def get_data(data, mode='train'):
    
    assert mode=='train' or mode=='test'
#     if mode=='train':
#         data['vesselNextportETA'] = pd.to_datetime(data['vesselNextportETA'], infer_datetime_format=True) # 转换时间
    if mode=='test':
        data['temp_timestamp'] = data['timestamp']
        data['onboardDate'] = pd.to_datetime(data['onboardDate'], infer_datetime_format=True)
    
    data['timestamp'] = pd.to_datetime(data['timestamp'], infer_datetime_format=True)
    return data

test_data = get_data(test_data, mode='test')

test_data.sort_values(['loadingOrder', 'timestamp'], inplace=True)
test_data = test_data.reset_index(drop=True) 

test_data = test_data.merge(result[['loadingOrder', 'ETA']], on='loadingOrder', how='left')
test_data['ETA'] = test_data['ETA'].apply(lambda x:x.strftime('%Y/%m/%d  %H:%M:%S'))
test_data.drop(['direction','TRANSPORT_TRACE'],axis=1,inplace=True)
test_data['onboardDate'] = test_data['onboardDate'].apply(lambda x:x.strftime('%Y/%m/%d  %H:%M:%S'))
test_data['creatDate'] = pd.datetime.now().strftime('%Y/%m/%d  %H:%M:%S')
test_data['timestamp'] = test_data['temp_timestamp']
# 整理columns顺序
result = test_data[['loadingOrder', 'timestamp', 'longitude', 'latitude', 'carrierName', 'vesselMMSI', 'onboardDate', 'ETA', 'creatDate']]
# Out:
# /opt/conda/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:23: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.

# %%
result
# Out:
#          loadingOrder                 timestamp   longitude   latitude  \
# 0      AE223035353902  2019-07-03T21:16:48.000Z  120.093858  22.581320
# 1      AE223035353902  2019-07-03T21:34:48.000Z  120.035707  22.617522
# 2      AE223035353902  2019-07-03T21:51:18.000Z  119.981800  22.658465
# 3      AE223035353902  2019-07-03T21:54:18.000Z  119.970845  22.668688
# 4      AE223035353902  2019-07-03T22:11:08.000Z  119.953628  22.756897
# ...               ...                       ...         ...        ...
# 34707  ZZ524449869421  2020-03-17T04:02:38.000Z  103.776707   1.252897
# 34708  ZZ524449869421  2020-03-17T04:03:18.000Z  103.776312   1.253418
# 34709  ZZ524449869421  2020-03-17T04:05:18.000Z  103.775175   1.254865
# 34710  ZZ524449869421  2020-03-17T04:05:58.000Z  103.774803   1.255285
# 34711  ZZ524449869421  2020-03-17T04:07:38.000Z  103.773883   1.256368
#
#       carrierName   vesselMMSI           onboardDate                   ETA  \
# 0          OIEQNT  C2075927370  2019/07/02  04:12:48  2019/07/26  03:43:57
# 1          OIEQNT  C2075927370  2019/07/02  04:12:48  2019/07/26  03:43:57
# 2          OIEQNT  C2075927370  2019/07/02  04:12:48  2019/07/26  03:43:57
# 3          OIEQNT  C2075927370  2019/07/02  04:12:48  2019/07/26  03:43:57
# 4          OIEQNT  C2075927370  2019/07/02  04:12:48  2019/07/26  03:43:57
# ...           ...          ...                   ...                   ...
# 34707      BHSOUA  P2595193878  2020/03/13  06:07:28  2020/04/01  04:40:59
# 34708      BHSOUA  P2595193878  2020/03/13  06:07:28  2020/04/01  04:40:59
# 34709      BHSOUA  P2595193878  2020/03/13  06:07:28  2020/04/01  04:40:59
# 34710      BHSOUA  P2595193878  2020/03/13  06:07:28  2020/04/01  04:40:59
# 34711      BHSOUA  P2595193878  2020/03/13  06:07:28  2020/04/01  04:40:59
#
#                   creatDate
# 0      2020/06/27  08:10:30
# 1      2020/06/27  08:10:30
# 2      2020/06/27  08:10:30
# 3      2020/06/27  08:10:30
# 4      2020/06/27  08:10:30
# ...                     ...
# 34707  2020/06/27  08:10:30
# 34708  2020/06/27  08:10:30
# 34709  2020/06/27  08:10:30
# 34710  2020/06/27  08:10:30
# 34711  2020/06/27  08:10:30
#
# [34712 rows x 9 columns]

# %%
result.to_csv('data/B_lgb_10fold.csv', index=False)
